# %%
{"Settings": {"story_id": "", "story_name": "生化危机7(Resident Evil 7)", "story_style": ["恐怖生存", "心理惊悚", "阴森诡异", "紧张刺激", "黑暗神秘", "家庭悲剧", "超自然现象"], "leading_role": "伊森·温特斯", "story_desc": "故事发生在2017年，美国路易斯安那州的一个偏僻农场，伊森·温特斯收到了一段来自失踪三年的妻子米娅的神秘录像，指引他前往贝克家族的庄园。贝克家族是一个被感染的家庭，他们的行为变得极其暴力和疯狂。伊森在寻找妻子的过程中，逐渐揭开了庄园背后的恐怖秘密。", "story_goal": "伊森的主要目标是找到并拯救他的妻子米娅，同时揭开贝克家族庄园的秘密，并设法逃离这个充满危险的地方。在过程中，他需要面对被感染的贝克家族成员和其他恐怖的生物，解开谜题，并逐步了解事件的真相。", "story_chars": {"伊森·温特斯": "身份标签", "米娅·温特斯": "身份标签", "伊芙琳": "身份标签", "杰克·贝克": "身份标签", "玛格丽特·贝克": "身份标签", "卢卡斯·贝克": "身份标签"}, "storylines": ["寻找米娅:伊森·温特斯收到失踪三年的妻子米娅的消息，前往路易斯安那州的贝克家族庄园寻找她。", "逃离庄园:伊森在庄园中发现米娅被感染并攻击他，他被迫击败她并继续探索庄园寻找逃脱的方法。", "对抗贝克家族:伊森遭遇贝克家族的成员，包括杰克、玛格丽特和卢卡斯，他们被感染并变得极其危险，伊森必须与他们战斗以求生存。", "揭示真相:伊森发现感染的源头是一个名叫伊芙琳的小女孩，她具有控制人心的能力，贝克家族因她而变得疯狂。", "拯救米娅:伊森找到米娅并试图解救她，同时必须面对伊芙琳的最终形态，揭开她的真实身份并阻止她的计划。", "逃出生天:伊森成功击败伊芙琳，解救米娅并逃离庄园，最终被救援人员接走，结束了这场噩梦。"], "story_info": {"epi_struct": "multi", "gen_end_num": 3, "pre_epi_node": {"1": [0], "2": [1], "3": [2], "4": [3], "5": [3], "6": [4], "7": [5], "8": [6], "9": [7], "10": [8], "11": [9], "12": [10], "13": [11], "14": [12], "15": [13], "16": [11]}, "language": "中文", "sources ": "", "sources": "game"}, "states": {"0": {"seq": [1, 2, 3, 5, 7, 9, 11, 16], "Eva_outline_ori_think": "基础结构(15/20): 故事大部分章节以伊森·温特斯的视角展开，核心目标明确且贯穿始终。然而，episode 11和episode 16存在重复事件，导致扣分。时间轴单向流动，没有倒叙或插叙。\n连贯性(18/20): 整体章节剧情较为连贯，相邻章节保持时间和逻辑连续性，非相邻章节通过伏笔和线索形成隐性关联。但episode 11和episode 16的重复内容略微影响整体连贯性。\n合理性(18/20): 整体剧情形成完整闭环，前后逻辑合理，事件发生自然，符合世界观和人物性格。重复事件在合理性上略有影响。\n完整性(17/20): 整体剧情完整，前期剧情对后期有影响，节奏大体合理。但episode 11和episode 16的重复使得部分剧情显得冗余。\n吸引性(19/20): 整体故事引人入胜，节奏合理，具有悬念和高潮。重复事件对吸引性影响较小。\n", "Eva_outline_ori_score": 87}, "1": {"seq": [1, 2, 3, 5, 7, 9, 11, 13, 15], "Eva_outline_ori_think": "基础结构(15/20): 主角伊森·温特斯的视角贯穿始终，核心目标明确。然而，episode 15与episode 13的内容几乎重复，导致事件重复性问题，扣5分。连贯性(18/20): 整体剧情连贯，相邻章节保持时间和逻辑连续性，但episode 15与episode 13的重复导致相邻章节重叠，扣2分。合理性(18/20): 整体剧情形成闭环，逻辑合理，符合世界观和人物性格，但重复事件影响合理性，扣2分。完整性(15/20): 整体剧情完整，前期剧情对后期有影响，但episode 15的重复使得结局显得拖沓，扣5分。吸引性(18/20): 整体故事引人入胜，节奏合理，有悬念和高潮，但重复事件削弱了部分吸引力，扣2分。", "Eva_outline_ori_score": 84, "Eva_outline_refine_think": "基础结构(15/20): 主角伊森的视角始终贯穿，核心目标明确。但episode 13和15的事件重复，扣5分。时间轴单向流动。连贯性(18/20): 整体剧情连贯，相邻章节逻辑连续，非相邻章节通过伏笔关联。但episode 13和15内容重复，扣2分。合理性(20/20): 整体形成闭环，剧情逻辑合理，符合世界观和人物性格。完整性(18/20): 整体完整，前期对后期有影响，但episode 11米娅的牺牲有些突兀，扣2分。吸引性(20/20): 故事引人入胜，节奏合理，有悬念和高潮。", "Eva_outline_refine_score": 91}, "2": {"seq": [1, 2, 3, 4, 6, 8, 10, 12, 14], "Eva_outline_ori_think": "基础结构(15/20): 主角视角和核心目标明确，但episode 14与episode 12重复，扣5分。时间轴单向流动。连贯性(15/20): 整体连贯性较好，但episode 12与episode 14内容重复，扣5分。合理性(18/20): 整体逻辑合理，符合世界观，但重复事件导致轻微扣分。完整性(15/20): 故事基本完整，但重复事件影响节奏，扣5分。吸引性(18/20): 故事有趣，节奏合理，有悬念和高潮，但重复事件略微影响吸引力，扣2分。", "Eva_outline_ori_score": 81, "Eva_outline_refine_think": "基础结构(15/20): 主角伊森·温特斯的视角和核心目标明确，但episode 12和episode 14内容重复，导致扣分。时间轴基本单向流动，没有倒叙或插叙。\n连贯性(18/20): 整体章节剧情连贯，相邻章节保持时间和逻辑连续性，但episode 12和episode 14内容重复，影响了非相邻章节的隐性关联。\n合理性(18/20): 整体形成闭环，前后剧情逻辑合理，但重复的内容在合理性上略显不足。\n完整性(15/20): 整体剧情较完整，但episode 12和episode 14的重复使得结局显得不够紧凑，影响了节奏。\n吸引性(17/20): 故事整体有趣，引人入胜，节奏合理，存在悬念和高潮，但重复内容略微削弱了吸引力。\n", "Eva_outline_refine_score": 83}}, "gen_parameter": {"data_folder": "storyline_generator/story_framework_data", "combine_episode_num": 1, "seg_main_episode_num": 10, "use_language": 0, "story_branch_num": 2, "if_single_episode": false, "if_role_known": false, "stroy_source": "game", "use_rag_know": 0}}, "Episodes": [{"episode_id": 1, "pre_episode_id": [0], "episode_goal": "伊森·温特斯的主要目标是找到失踪三年的妻子米娅，并了解她失踪的真相。", "episode_scene": "伊森·温特斯收到一条来自失踪三年的妻子米娅的神秘消息，指引他前往美国路易斯安那州的贝克家族庄园。这个庄园位于偏远的乡村地区，周围环境阴森恐怖，充满了未知的危险和谜团。伊森在夜幕降临时抵达庄园，准备展开他的寻找之旅。", "episode_desc": "伊森·温特斯接到一封神秘的邮件，发件人自称是他失踪三年的妻子米娅。邮件中附有一个地址，位于路易斯安那州的贝克家族庄园。伊森心中充满疑惑和希望，决定亲自前往庄园寻找米娅的下落。驱车驶入庄园附近，阴森的环境和破败的建筑让他感到不安，但他坚定地走向庄园，准备面对未知的挑战。", "episode_chars": ["伊森·温特斯: 坚韧且富有决心。作为一名普通的白领，他因妻子的失踪而心力交瘁，但在收到米娅的消息后，他毫不犹豫地踏上了寻找她的旅程。伊森此时充满了希望和不安，渴望解开妻子失踪的谜团。", "米娅·温特斯: 神秘而复杂。她在三年前突然失踪，留下了一个无法解释的空白。米娅的消息让人感到困惑，她的现状和动机尚不明确，成为伊森此行的核心谜题。"], "extra_info": [], "triggers": [{"condition": "<IF> **伊森·温特斯在贝克家族庄园外发现了一些异常迹象，这些迹象暗示米娅可能在庄园内，并且处于危险之中。伊森的内心驱动力是对妻子的深切思念和渴望解开她失踪的谜团，这促使他不顾个人安危，决定进入庄园。** <THEN> **伊森进入庄园后，发现环境阴森恐怖，并找到一段米娅留下的录像。录像中米娅的求救信息进一步确认她被困在地下室，这使得伊森的目标更加明确，推动他继续深入探索庄园，寻找妻子的下落。**", "next_episode": 2, "eva_reason_ori": "时间连贯性(15/20): <IF>部分提到伊森在庄园外发现异常迹象，但没有明确的时间点延展，导致时间连贯性稍显不足。<THEN>部分在进入庄园后找到录像带，时间上较为连贯。扣分原因：<IF>缺乏明确的时间点延展。\n剧情流程性(18/20): 整体跳转事件较为流畅自然，伊森的驱动力和进入庄园后的发现形成了合理的剧情连接。扣分原因：<IF>部分的异常迹象描述稍显模糊。\n事件合理性(17/20): 伊森因妻子的失踪而进入庄园符合逻辑，但<IF>部分的异常迹象未具体化，稍显不合理。扣分原因：异常迹象的合理性不足。\n主体关联性(20/20): 触发条件由伊森的行为直接引发，符合主体关联性。\n逻辑完整性(18/20): <IF>部分包含了多个条件而非单一可验证条件，影响逻辑完整性。<THEN>部分较为独立。扣分原因：<IF>条件过于复杂。\n", "eva_score_ori": 88}], "message_pairs": [], "episdoe_desc_brief": "寻找米娅: 伊森·温特斯收到失踪三年的妻子米娅的消息，前往路易斯安那州的贝克家族庄园寻找她。"}, {"episode_id": 2, "pre_episode_id": [1], "episode_goal": "伊森的主要目标是进入庄园，寻找他的妻子米娅，并解开她失踪的谜团。", "episode_scene": "伊森·温特斯在收到一封来自失踪三年的妻子米娅的神秘信件后，来到路易斯安那州的一座偏僻庄园。庄园的环境阴森恐怖，四周弥漫着不祥的气息，时间是夜晚，四周寂静无声，给人一种压抑和不安的感觉。", "episode_desc": "伊森·温特斯推开贝克家族庄园的大门，迎面而来的腐朽气息和阴森的氛围让他不寒而栗。庄园内光线昏暗，墙壁斑驳，地板嘎吱作响，仿佛诉说着不为人知的秘密。他小心翼翼地探索着，试图找到任何有关米娅的线索。在一间破旧的房间里，他发现了一台老旧的录像机和一盘录像带。伊森插入录像带，屏幕上出现了米娅的身影。录像中的米娅神情憔悴，语气急促，暗示她被困在庄园的地下室。伊森心中一紧，意识到米娅可能正处于危险之中。他决心深入探索，寻找通往地下室的入口，救出自己的妻子。", "episode_chars": ["伊森·温特斯: 坚韧不拔，充满勇气和决心。为了寻找失踪的妻子，他不顾危险进入了这个神秘的庄园。他对米娅的爱和对真相的渴望驱使着他不断前行。", "米娅·温特斯: 神秘且复杂。她失踪多年后突然与伊森联系，暗示自己可能被困在庄园的地下室。她的现状不明，给人一种既熟悉又陌生的感觉。"], "extra_info": [], "triggers": [{"condition": "<IF> **伊森在庄园中发现米娅留下的录像，录像中暗示她可能被困在地下室，这一信息激发了伊森强烈的求生欲望和对米娅的关切之情，促使他决定深入调查。** <THEN> **伊森根据录像中的线索，找到通往地下室的入口，并在地下室中发现被感染的米娅。她在短暂清醒后攻击伊森，迫使他做出艰难的选择：是击败米娅以自保，还是尝试控制她以拯救她。这个选择直接影响到伊森的下一步行动和情节的发展。**", "next_episode": 3, "eva_reason_ori": "时间连贯性(15/20): <IF>中提到的录像带发现和伊森的决心在当前章结尾处延展的时间点合理，但<THEN>中直接跳转到地下室，缺乏具体的时间过渡。剧情流程性(15/20): 跳转事件连接不够流畅，自录像带到地下室的过渡略显突兀，缺少中间的探索过程。事件合理性(18/20): 跳转事件基本符合逻辑，伊森的行为动机与故事背景一致，但对地下室入口的发现缺乏详细描述。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(15/20): <IF>条件较为复杂，包含了多个因素，如求生欲望和关切之情，建议简化为单一可验证条件。<THEN>部分包含了后续情节的复述，建议仅描述独立事件。", "eva_score_ori": 83}], "message_pairs": [], "episdoe_desc_brief": "初入庄园: 伊森进入庄园，发现环境阴森恐怖，并找到一段米娅留下的录像，提示她可能被困在地下室。"}, {"episode_id": 3, "pre_episode_id": [2], "episode_goal": "伊森的主要目标是面对被感染的米娅，做出是否击败她或尝试控制她的选择，以便继续探索和解开背后的谜团。", "episode_scene": "伊森在贝克家族的庄园中探索时，进入了阴暗潮湿的地下室。这个地下室充满了腐烂和恐怖的气息，墙壁上布满了霉菌和血迹，四周弥漫着令人窒息的压迫感。在这里，伊森发现了被感染的米娅，并面临艰难的选择。", "episode_desc": "伊森·温特斯在贝克家族庄园的地下室中找到被感染的米娅。她的面容憔悴，眼神中透露出一丝清醒。伊森试图与她沟通，但米娅突然情绪失控，向他发起攻击。面对突如其来的危险，伊森心中挣扎不已。他必须在保护自己的同时，尝试唤醒米娅的理智。米娅的攻击愈发猛烈，伊森被迫做出艰难的选择：是击败眼前的米娅，还是冒险尝试控制她，以期恢复她的清醒。在这个充满绝望与希望的时刻，伊森的每一个决定都可能改变他们的命运。", "episode_chars": ["伊森·温特斯: 勇敢而坚韧，充满求生欲望和对妻子的深切关怀。此时他正努力寻找失踪的妻子米娅，并被迫面对各种恐怖和超自然的威胁。", "米娅·温特斯: 曾经温柔善良，但现在被感染后变得不稳定且具有攻击性。在短暂清醒时，她仍然表现出对伊森的爱和关心，但很快又被感染控制，变得极具威胁性。"], "extra_info": [], "triggers": [{"condition": "<IF>伊森在压制米娅攻击时未能及时控制其暴走状态 <THEN>米娅倒地时体内溢出的霉菌引发地下室剧烈震动，暴露墙体隐藏的暗道入口", "next_episode": 4, "eva_reason_ori": "时间连贯性(12/20): <IF>部分描述了伊森意识到米娅短暂清醒的机会和失控的威胁，但在时间点的延展上不够明确，缺乏对具体时间节点的清晰描述。<THEN>部分虽然承接了伊森的决心，但未能独立于下章开篇的衔接事件。剧情流程性(15/20): 整体流程较为自然，但<IF>中伊森的选择过程略显仓促，缺乏对选择过程的详细刻画，使得跳转事件的流畅性稍有欠缺。事件合理性(16/20): 跳转事件在逻辑上基本合理，符合故事背景和人物行为，但伊森的选择似乎过于直接，缺乏对其内心挣扎的深入探讨。主体关联性(18/20): 触发条件由伊森的行为直接引发，符合主角的角色设定。逻辑完整性(14/20): <IF>部分包含多个条件和事件描述，显得不够单一和明确；<THEN>部分虽然包含独立事件，但与章节内容复述的界限不够清晰。", "eva_score_ori": 75, "eva_opt_ori": "原触发事件中<IF>同时包含心理抉择和物理动作，不符合单一可验证条件要求。根据评估结果，需聚焦于主角可验证的物理动作作为触发条件。将米娅最终失控作为触发点，既符合当前情节结尾延展的时间点，又能直接引发后续事件。<THEN>需要建立独立衔接事件而非复述下章内容，通过环境异变作为击败行为的直接后果，既保持恐怖生存风格，又形成自然过渡。", "old_con": "<IF> **伊森在地下室面对被感染的米娅时，意识到她的短暂清醒是他与妻子重新建立联系的唯一机会，但同时也感受到她再次失控的威胁迫在眉睫。伊森必须在保护自己的安全和对妻子的深切关怀之间做出艰难选择，最终决定击败米娅以确保自身的生存，并继续寻找解开感染谜团的方法。** <THEN> **伊森在痛苦中击败米娅后，意识到自己必须尽快找到逃离庄园的方法，同时也要揭开感染背后的真相，以便为米娅和自己寻求最终的救赎。他的决心和求生欲望驱使他继续探索庄园，面对接下来的未知威胁和挑战。**", "eva_reason_opt": "时间连贯性(10/20): <IF>的时间点不明确，未能有效承接当前章节结尾，<THEN>未能独立于下章开篇的事件。剧情流程性(15/20): 跳转事件存在一定的逻辑，但不够流畅自然，<IF>的条件在当前情节中不够明确。事件合理性(10/20): 霉菌引发地下室震动的设定缺乏合理性，与故事背景不完全一致。主体关联性(15/20): 触发条件与伊森的行为有一定关联，但不够直接。逻辑完整性(10/20): <IF>条件不够单一明确，<THEN>事件缺乏独立性。", "eva_score_opt": 60}, {"condition": "<IF>伊森在被米娅压制时触碰到实验台遗留的镇定药剂注射器 <THEN>注射器内残余血清使米娅进入短暂休眠状态，其手腕浮现发光的霉菌纹路指向走廊方向", "next_episode": 5, "eva_reason_ori": "时间连贯性(10/20): <IF>中提到的意识到米娅的短暂清醒作为重新建立联系的机会，但这个意识并没有在当前章结尾明确发生，缺乏时间点的延展性。<THEN>中伊森的决定虽然是衔接事件，但没有独立于下章开篇。剧情流程性(15/20): 跳转事件的连接较为自然，但<IF>中的意识到米娅的清醒并没有在当前情节之后的明确条件。事件合理性(18/20): 伊森尝试控制米娅而不是击败她符合他的性格和故事背景。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(12/20): <IF>包含多个意识和动机，缺乏单一可验证条件，<THEN>包含的事件较多，未能独立于章节内容。", "eva_score_ori": 75, "eva_opt_ori": "原<IF>包含意识觉醒和心理动机等非行为要素，不符合单一可验证条件要求，且时间点未延展至当前情节之后。原<THEN>与下章开篇存在内容重叠，未形成独立衔接事件。改进后聚焦伊森在战斗中的具体行为触发控制结果，通过药剂注射建立与后续解药线索的因果链", "old_con": "<IF> **伊森在地下室面对被感染的米娅时，意识到她的短暂清醒不仅是重新建立联系的机会，也是揭示感染背后真相的关键线索。他感受到米娅内心深处仍然存在的善良和对他的爱，这促使他尝试控制她，而不是击败她。伊森的内心驱动力是对妻子的深切关怀和对解开感染谜团的渴望。** <THEN> **伊森成功控制住米娅的攻击，决定带她一起寻找解药。他意识到，米娅的清醒状态可能会提供关于感染的重要信息，这将帮助他们揭开谜团并找到治愈的方法。伊森的选择开启了他们共同面对庄园中隐藏的更深层次威胁的旅程。**", "eva_reason_opt": "时间连贯性(10/20): <IF>中提到的触碰注射器事件在当前plot中没有明确的时间点延展，且<THEN>的镇定效果与下章开篇的对抗不够连贯。剧情流程性(15/20): 虽然触碰注射器的事件可以在当前情节中达成，但其效果与下章的对抗情节衔接不够自然。事件合理性(10/20): 注射器的出现和作用缺乏足够的背景支持，镇定效果过于便利且与故事背景不符。主体关联性(15/20): 触发条件由伊森的行为引发，但缺乏足够的动机和背景支持。逻辑完整性(10/20): <IF>条件不够单一且具体，<THEN>包含的事件过于复杂，缺乏清晰的因果关系。", "eva_score_opt": 60}], "message_pairs": [], "episdoe_desc_brief": "地下室的选择: 伊森在地下室找到被感染的米娅，她在短暂清醒后攻击伊森。伊森面临选择:击败米娅或尝试控制她。"}, {"episode_id": 4, "pre_episode_id": [3], "episode_goal": "伊森·温特斯的主要目标是寻找逃脱贝克家族庄园的方法，并继续探索庄园。", "episode_scene": "伊森·温特斯在寻找失踪的妻子米娅的过程中，来到美国路易斯安那州的一个偏远庄园。这个庄园属于贝克家族，庄园内充满了恐怖和神秘的氛围，环境阴森且充满危险。伊森在庄园中不断遭遇超自然的现象和敌对的家族成员，必须在这个充满未知的地方寻找生存和逃脱的途径。", "episode_desc": "伊森·温特斯在地下室与米娅的激烈对抗中，心中充满了痛苦和无奈。米娅的攻击毫不留情，伊森被迫在自卫与拯救之间做出艰难的抉择。最终，伊森忍痛击败了米娅，看到她倒下的瞬间，他的心仿佛被撕裂。尽管如此，他知道自己必须继续前行，寻找逃离这个恐怖庄园的方法。他擦去脸上的汗水，坚定地走出地下室，继续在阴暗的走廊中探索，希望能找到一条通往自由的出路。庄园内的每一个角落都充满了未知的危险，但伊森心中只有一个信念，那就是活着离开这里，并找出这一切背后的真相。", "episode_chars": ["伊森·温特斯: 坚韧且富有求生意志的普通人，因妻子米娅的失踪而来到贝克家族庄园。在面对恐怖和危险时展现出勇敢和决心，努力寻找妻子并逃离庄园。", "米娅·温特斯: 伊森的妻子，曾失踪多年，性格复杂，时而温柔时而暴力。她在庄园中被发现，但似乎受到了某种控制，行为变得不可预测，给伊森带来了极大的困扰和挑战。"], "extra_info": [], "triggers": [{"condition": "<IF> **伊森在击败米娅后，意识到庄园内的威胁远不止于此，并发现了一些线索暗示贝克家族的成员是庄园中更大的威胁。他的求生意志和对妻子的责任感驱使他继续探索庄园，寻找逃脱的方法。** <THEN> **伊森深入庄园，遭遇贝克家族的成员杰克、玛格丽特和卢卡斯。他们的极端行为和对伊森的敌意迫使他不得不与他们对抗，以求生存并继续寻找逃脱的途径。**", "next_episode": 6, "eva_reason_ori": "时间连贯性(15/20): <IF>中提到伊森意识到庄园内的威胁并发现线索，这些内容在当前情节结尾并未明确展现，扣5分。<THEN>部分与下一情节开篇的衔接较为自然。\n剧情流程性(15/20): <IF>条件在当前情节之后可以达成，但缺乏明确的过渡细节，扣5分。\n事件合理性(18/20): 跳转事件总体合理，但<IF>中提到的线索发现没有具体描述，略显突兀，扣2分。\n主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。\n逻辑完整性(15/20): <IF>条件描述较为模糊，未能形成单一可验证条件，扣5分。<THEN>部分包含独立事件，符合要求。", "eva_score_ori": 83}], "message_pairs": [], "episdoe_desc_brief": "击败米娅: 伊森被迫击败米娅，继续探索庄园寻找逃脱的方法。"}, {"episode_id": 5, "pre_episode_id": [3], "episode_goal": "伊森的主要目标是控制住米娅的攻击，并带她一起寻找解药，以便解决当前的困境。", "episode_scene": "伊森在一个被遗弃的庄园中，庄园位于路易斯安那州的一个偏远地区。时间是深夜，环境阴森恐怖，充满了未知的危险和谜团。庄园内部破败不堪，充满了腐朽的气息，四周寂静无声，偶尔传来令人毛骨悚然的声音。", "episode_desc": "伊森·温特斯在地下室与被感染的米娅展开激烈的对抗。米娅的攻击迅猛而疯狂，但伊森心中仍存有一丝希望，他相信自己的妻子仍在这具被感染的躯壳中。经过一番挣扎，伊森设法控制住米娅的攻击，暂时平息了她的狂暴状态。他小心翼翼地将她束缚住，避免她再次失控。米娅的眼神中闪烁着痛苦与挣扎，似乎在与体内的感染抗争。伊森心中明白，必须尽快找到解药，才能真正拯救米娅。他决定带上米娅，一同在庄园中寻找可能的解药线索。两人步履蹒跚地穿过阴暗的走廊，伊森紧握着米娅的手，誓言无论多么艰难，都要带她重返光明。", "episode_chars": ["伊森·温特斯: 坚韧不拔，勇敢且充满决心。他是一个普通的白领，因为收到失踪妻子米娅的消息而来到庄园。他在寻找米娅的过程中遭遇了许多危险，但始终坚持不懈，试图解救妻子并逃离险境。", "米娅·温特斯: 情绪不稳定，时而温柔时而狂暴。她是伊森的妻子，曾失踪多年，现被困在庄园中。米娅在被控制时会攻击伊森，但她内心仍然渴望被解救和恢复正常。"], "extra_info": [], "triggers": [{"condition": "<IF>伊森确认米娅的束缚装置足以维持十分钟安全期后，将地下室出口作为优先行动方向 <THEN>两人穿过渗水的储藏间时，米娅被铁门锈蚀声刺激突然挣扎，导致伊森发现暗门后的化学试剂气味", "next_episode": 7, "eva_reason_ori": "时间连贯性(10/20): <IF>中提到的伊森安抚米娅和意识到危险的时间点与当前章节结尾的时间点不够明确，缺乏具体的时间过渡。<THEN>中的行动动机虽有，但缺乏独立的衔接事件。剧情流程性(15/20): 整体流程较为自然，但<IF>中的条件似乎过于复杂，包含了多个事件。事件合理性(18/20): 跳转事件与故事背景和人物行为基本一致，但米娅在短暂清醒中透露线索的合理性稍显勉强。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(12/20): <IF>包含多个条件和事件描述，而非单一可验证条件；<THEN>部分缺乏独立事件，更多是章节内容的延续。", "eva_score_ori": 75, "eva_opt_ori": "原<IF>存在多重条件堆砌(安抚/控制/恢复理智/意识危险)且时间锚点模糊，违反单一可验证原则。原<THEN>直接复现下章核心线索发现过程，缺乏独立衔接层。改进后以「行动决策」作为触发点，建立「环境移动」作为物理过渡层。", "old_con": "<IF> **伊森成功地安抚并暂时控制住米娅的攻击行为，使她恢复片刻的理智，意识到继续留在原地只会带来更大的危险。伊森的主要目标是确保米娅的安全，并带她一起寻找解药，以便解决当前的困境。** <THEN> **米娅在短暂的清醒中透露了关于庄园中可能藏有解药的线索，激发了伊森的希望和行动动力。伊森决定带着米娅深入庄园，寻找解药的具体位置，这一决定将他们引向庄园更深处的未知区域，开启了新的冒险和挑战。**", "eva_reason_opt": "时间连贯性(15/20): <IF>中提到的'十分钟安全期'没有在当前plot中明确提及，导致时间连贯性略显不足。剧情流程性(18/20): 从地下室到庄园的过渡较为自然，但<THEN>中米娅挣扎的原因和后续发现化学试剂的过程稍显突兀。事件合理性(16/20): 米娅因铁门锈蚀声而挣扎的设定有些勉强，虽然符合恐怖生存的风格，但与故事背景的紧张氛围不完全一致。主体关联性(20/20): 伊森的行为直接引发了事件的发生，符合要求。逻辑完整性(18/20): <IF>条件较为明确，但<THEN>中的事件描述稍显复杂，影响了逻辑的简洁性。", "eva_score_opt": 87}], "message_pairs": [], "episdoe_desc_brief": "控制米娅: 伊森设法控制住米娅的攻击，决定带她一起寻找解药。"}, {"episode_id": 6, "pre_episode_id": [4], "episode_goal": "伊森·温特斯的核心目标是对抗并击败贝克家族的成员，以求在这片危险的环境中生存下来。", "episode_scene": "伊森·温特斯在寻找失踪的妻子米娅的过程中，来到了一处偏僻的路易斯安那州的农场。这片农场被茂密的森林包围，阴森恐怖，充满了腐朽和危险的气息。时间是夜晚，环境昏暗，四周静谧而令人不安，给人一种随时可能遭遇危险的紧迫感。", "episode_desc": "伊森·温特斯在庄园的走廊中继续前行，突然遭遇贝克家族的成员。杰克·贝克出现在他的面前，面目狰狞，毫无理智地向伊森发起攻击。伊森迅速反应，利用手中的武器与杰克展开激烈搏斗。尽管杰克力大无穷，但伊森凭借机智与勇气，勉强将其击退。随后，伊森继续探索，遇到了玛格丽特·贝克，她的身体被感染后变得极其怪异，操控着一群昆虫攻击伊森。伊森艰难地躲避着，寻找机会反击，最终成功将玛格丽特击败。就在他以为可以松一口气时，卢卡斯·贝克的陷阱又让他陷入新的危机。伊森小心翼翼地破解卢卡斯设置的机关，心中明白他必须保持警惕，才能在这个充满危险的庄园中生存下去。每一次与贝克家族的对抗都让伊森更加坚定，他知道只有击败这些被感染的敌人，才能找到逃出生天的希望。", "episode_chars": ["伊森·温特斯: 坚韧且富有求生本能的普通人。他在寻找妻子的过程中被卷入了贝克家族的恐怖事件中，必须依靠智慧和勇气来面对各种危险。", "杰克·贝克: 贝克家族的父亲，性格狂暴且具有攻击性。他被感染后变得极其危险，常常以暴力和恐怖的方式对待入侵者。", "玛格丽特·贝克: 贝克家族的母亲，性格阴险且狡诈。她被感染后具有操控昆虫的能力，常常利用环境来对付敌人。", "卢卡斯·贝克: 贝克家族的儿子，性格狡猾且具有恶作剧心理。他喜欢设置陷阱和谜题来折磨和戏弄他人。"], "extra_info": [], "triggers": [{"condition": "<IF> **伊森在与贝克家族的对抗中逐渐意识到，单纯的武力对抗无法彻底解决问题，他需要寻找导致贝克家族疯狂的根源，以便从根本上解除威胁** <THEN> **伊森在一次与贝克家族成员的激烈交锋中，偶然发现了一些关于伊芙琳的线索，这些线索指向了感染的源头，促使他开始调查伊芙琳的真实身份和她的能力，从而引导剧情进入揭示真相的阶段**", "next_episode": 8, "eva_reason_ori": "时间连贯性(15/20): 当前<IF>中提到伊森意识到需要寻找根源，但没有明确的时间点或事件作为触发，缺乏具体的时间连贯性。剧情流程性(15/20): <IF>与<THEN>之间的连接较为模糊，伊森的意识转变与线索发现之间的自然过渡不够清晰。事件合理性(18/20): 伊森意识到需要寻找根源是合理的，但偶然发现线索的描述略显随意。主体关联性(20/20): <IF>明确由伊森的意识转变引发，符合主体关联性。逻辑完整性(15/20): <IF>条件描述较为笼统，不够具体，<THEN>事件描述较为完整，但缺乏明确的触发条件。", "eva_score_ori": 83}], "message_pairs": [], "episdoe_desc_brief": "对抗贝克家族: 伊森遭遇贝克家族的成员，包括杰克、玛格丽特和卢卡斯，他们被感染并变得极其危险，伊森必须与他们战斗以求生存。"}, {"episode_id": 7, "pre_episode_id": [5], "episode_goal": "伊森的主要目标是找到解药，以治愈米娅并解除她身上的诅咒。", "episode_scene": "伊森和米娅在贝克家族的庄园中寻找解药的线索。这个庄园位于路易斯安那州的偏远地区，四周被沼泽地包围，环境阴森恐怖，充满了未知的危险和谜团。庄园内的建筑破旧不堪，充满了神秘和诡异的氛围。", "episode_desc": "伊森和米娅在庄园中继续寻找解药的线索。他们穿过一间又一间破败的房间，墙壁上斑驳的壁纸和地板上厚厚的灰尘无不昭示着这里的荒废。伊森小心翼翼地翻找每一个抽屉和柜子，试图找到任何可能的线索。米娅虽然被束缚，但她的眼神中透露出一丝清醒，偶尔会低声提醒伊森注意周围的动静。两人来到一间实验室，墙上挂满了复杂的化学公式和实验记录。伊森在一堆杂物中发现了一本发黄的笔记，里面详细记录了某种病毒的研究过程和可能的解药配方。尽管笔记的内容晦涩难懂，但伊森知道这可能是他们找到解药的关键。他们决定继续深入探索，希望能找到制作解药所需的材料和设备。", "episode_chars": ["伊森·温特斯: 坚韧不拔，勇敢且执着。为了拯救妻子米娅，他不顾自身安危深入险境。在寻找解药的过程中，他展现出强烈的求生意志和对妻子的深厚感情。", "米娅·温特斯: 复杂而神秘，内心深处充满挣扎。她被感染后性格变得不稳定，时而温柔时而暴躁。她对伊森的感情是真挚的，但被感染后常常无法控制自己的行为。"], "extra_info": [], "triggers": [{"condition": "<IF>伊森根据笔记配方线索走向地下室培养舱提取菌株样本时 <THEN>菌株共鸣引发米娅颅内寄生体剧烈抽搐，她突然夺过实验烧瓶砸碎培养舱，玻璃碎片划破手掌时眼中猩红与清明交替闪烁", "next_episode": 9, "eva_reason_ori": "时间连贯性(12/20): <IF>中提到的文件发现与米娅的意识恢复之间缺乏明确的时间点延展，导致时间连贯性不足。剧情流程性(15/20): 两个情节通过文件发现和米娅的觉醒连接，但米娅的觉醒过程略显突兀，缺乏自然过渡。事件合理性(16/20): 文件的发现和米娅的觉醒在逻辑上是合理的，但米娅的觉醒过程需要更清晰的解释。主体关联性(18/20): 伊森的行为直接导致了米娅的觉醒，符合主体关联性。逻辑完整性(14/20): <IF>条件包含了过多的事件描述，而非单一可验证条件，<THEN>部分的事件描述过于笼统，缺乏具体性。", "eva_score_ori": 75, "eva_opt_ori": "原IF包含多重条件（发现文件+解读内容+触发行动），不符合单一可验证条件规范。THEN过度预支下章核心冲突，导致衔接事件失去独立性。根据评估报告聚焦行为触发机制：将伊森执行文件指示作为触发点，衔接米娅因客体刺激产生的意识波动。", "old_con": "<IF> **伊森在庄园中发现一份关于解药的关键文件，这份文件揭示了解药的成分和制作方法，并暗示米娅的感染与贝克家族的某个秘密实验有关。伊森意识到必须找到实验室以获取解药的材料** <THEN> **米娅在伊森找到文件后逐渐恢复意识，她开始回忆起自己被感染的经过，并意识到自己曾经参与过实验。米娅的觉醒使她能够控制自己的行为，并决定帮助伊森寻找实验室，揭开贝克家族的秘密。两人联手对抗庄园中的危险，推动剧情进入下一阶段，揭示更多关于解药和感染的真相**", "eva_reason_opt": "时间连贯性(15/20): <IF>事件发生在当前章结尾处，但<THEN>事件的描述与下章开篇的时间点不够清晰，缺乏明确的时间过渡。剧情流程性(10/20): 从笔记线索到地下室的跳转缺乏自然的过渡，米娅的剧烈反应显得突兀。事件合理性(15/20): 米娅的反应与故事背景和人物性格有一定的契合，但夺过烧瓶并砸碎培养舱的行为逻辑不够充分。主体关联性(15/20): 触发条件由伊森的行为间接引发，但米娅的反应似乎更像是独立事件。逻辑完整性(10/20): <IF>条件不够单一，包含了多个动作和事件描述，<THEN>事件的独立性不够明确。", "eva_score_opt": 65}], "message_pairs": [], "episdoe_desc_brief": "寻找解药: 伊森和米娅在庄园中寻找解药的线索，试图治愈米娅。"}, {"episode_id": 8, "pre_episode_id": [6], "episode_goal": "伊森·温特斯的主要目标是揭示贝克家族疯狂行为背后的真相，并找到感染的源头。", "episode_scene": "伊森在贝克家族的庄园中探索，这个庄园位于路易斯安那州的偏远地区，环境阴森恐怖，充满了腐朽和被感染的迹象。时间是夜晚，整个庄园被一种不祥的气氛笼罩，伊森必须在这个危险的环境中寻找线索。", "episode_desc": "伊森·温特斯在庄园中继续探索，逐渐揭开了贝克家族疯狂背后的真相。他发现感染的源头是一个名叫伊芙琳的小女孩。伊芙琳拥有控制人心的能力，正是她的存在使得贝克家族变得疯狂。伊森在庄园的一个隐秘房间中找到了一些文件，这些文件详细记录了伊芙琳的背景和她的能力。文件显示，伊芙琳是一个实验的产物，被设计成一种生物武器。她的能力不仅能感染人类，还能操控他们的思想和行为。伊森意识到，只有找到并制止伊芙琳，才能结束这场噩梦。他心中充满了复杂的情感，对伊芙琳既有怜悯，也有警惕。他知道，自己必须面对这个小女孩，才能拯救自己和其他被困在庄园中的人。", "episode_chars": ["伊森·温特斯: 勇敢且执着，决心揭开妻子米娅失踪背后的谜团。在庄园中，他面临着巨大的心理和身体挑战，但仍然坚持不懈地寻找真相。", "伊芙琳: 表面上是一个小女孩，实际上是感染的源头，具有控制人心的能力。她的存在使得贝克家族变得疯狂，伊森需要面对她的威胁。", "贝克家族: 原本是普通的家庭，但在伊芙琳的影响下变得极其暴力和疯狂。他们的行为和庄园的变化都与伊芙琳的能力有关。"], "extra_info": [], "triggers": [{"condition": "<IF> **伊森在探索过程中发现了关于伊芙琳的更多信息，揭示她不仅是感染的源头，还具有更深层次的计划，这一发现使得伊森意识到必须尽快阻止她，以防止更大的灾难发生** <THEN> **伊森决定全力以赴去寻找并拯救被困的米娅，同时准备面对伊芙琳的最终形态，揭开她的真实身份并阻止她的计划，这一决心推动他进入下一阶段的对抗，直接引导剧情进入拯救米娅的情节**", "next_episode": 10, "eva_reason_ori": "时间连贯性(15/20): <IF>部分存在于当前章结尾处，但没有明确的时间点延展，缺乏具体的时间推进; <THEN>部分虽然推动剧情进入下一阶段，但没有独立的衔接事件。剧情流程性(18/20): 跳转事件连接较为流畅自然，<IF>条件在当前情节中可达成，但略显突兀。事件合理性(15/20): 跳转事件基本合理，但<IF>中提到的'更深层次的计划'未在当前情节中充分铺垫，与故事背景稍显脱节。主体关联性(20/20): <IF>条件由伊森的行为直接引发，符合角色动机。逻辑完整性(15/20): <IF>条件较为复杂，不够单一明确，<THEN>部分包含了较多的事件描述，缺乏独立性。", "eva_score_ori": 83}], "message_pairs": [], "episdoe_desc_brief": "揭示真相: 伊森发现感染的源头是一个名叫伊芙琳的小女孩，她具有控制人心的能力，贝克家族因她而变得疯狂。"}, {"episode_id": 9, "pre_episode_id": [7], "episode_goal": "伊森的主要目标是找到解药，帮助米娅恢复意识，并与她一起对抗贝克家族。", "episode_scene": "伊森在路易斯安那州的一个偏僻农场上，夜幕降临，周围环境阴森恐怖。这个农场是贝克家族的居住地，他们被一种神秘的病毒感染，变得极其危险。伊森在寻找解药的过程中，逐渐深入到这个充满危险和谜团的地方。", "episode_desc": "在贝克家族庄园的实验室中，米娅逐渐恢复意识，她的眼神不再迷茫，而是充满坚定。她开始帮助伊森寻找解药的线索。两人合作无间，米娅凭借对庄园的熟悉，指引伊森避开潜在的危险。她回忆起曾在庄园某处见过解药的线索，并带领伊森前往。途中，他们遭遇贝克家族的成员，米娅展现出惊人的勇气，与伊森并肩作战。她的觉醒让伊森倍感欣慰，仿佛看到了希望的曙光。在米娅的帮助下，伊森终于找到了解药的关键材料，两人迅速返回实验室，准备制作解药。米娅的觉醒不仅帮助伊森对抗贝克家族，也让他们的关系更加紧密。", "episode_chars": ["伊森·温特斯: 坚韧不拔，勇敢且充满决心。他是一个普通人，但为了寻找失踪的妻子米娅，他不惜深入险境。在当前情节中，他正在努力寻找解药，以便帮助米娅恢复意识。", "米娅·温特斯: 复杂而矛盾，曾被病毒控制但逐渐恢复意识。她是伊森的妻子，在被贝克家族囚禁并感染后，逐渐恢复了自己的意识，并开始帮助伊森对抗贝克家族。", "贝克家族: 充满敌意且极其危险。这个家族的成员被神秘病毒感染，变得异常凶残，成为伊森和米娅的主要威胁。"], "extra_info": [], "triggers": [{"condition": "<IF>伊森将关键材料投入解药配制装置启动合成程序时 <THEN>解药合成触发的能量波动激活米娅体内残留的伊芙琳意识，导致她突然跪地抓住实验台边缘，皮肤下浮现出与三年前录像带里相同的菌丝状纹路", "next_episode": 11, "eva_reason_ori": "时间连贯性(10/20): <IF>中米娅意识到威胁的过程没有明确的时间点延展，缺乏与当前章结尾的直接衔接。<THEN>中米娅的决定虽然独立，但没有明确的时间衔接。剧情流程性(15/20): 跳转事件在逻辑上可以理解，但缺乏自然的过渡，米娅的意识觉醒与牺牲之间的联系不够流畅。事件合理性(10/20): 米娅的牺牲动机虽然符合故事背景，但其觉醒与牺牲之间的逻辑转变显得突兀。主体关联性(15/20): 触发条件与伊森的行为关联较弱，主要是米娅的独立决策。逻辑完整性(10/20): <IF>包含了多个条件和事件描述，缺乏单一性。<THEN>虽然包含独立事件，但与<IF>的条件关联不够紧密。", "eva_score_ori": 60, "eva_opt_ori": "原触发条件存在三个核心缺陷：(1)触发主体错位导致关联性断裂 - 米娅的觉醒属于人物自主行为，未通过伊森行为触发；(2)条件复合化导致逻辑完整性不足 - 同时包含意识觉醒与威胁认知双重条件；(3)时间锚点缺失造成连贯性断裂。改进需将触发点锚定在伊森完成解药配置时引发的连锁反应，使米娅的牺牲决策成为伊森关键行为的直接后果。", "old_con": "<IF> **米娅在恢复意识的过程中，逐渐意识到伊芙琳对她和伊森的威胁，并深刻理解到只有通过牺牲自己才能彻底解除这种威胁，从而帮助伊森完成他的主要目标，即找到解药并与她一起对抗贝克家族** <THEN> **米娅在意识到这一点后，决定牺牲自己以削弱伊芙琳的力量，为伊森创造一个更有利的机会去击败伊芙琳。这一决定不仅体现了她对伊森的爱和保护，也为接下来的剧情发展奠定了基础，推动伊森继续前行，直面最终的敌人伊芙琳**", "eva_reason_opt": "时间连贯性(15/20): <IF>条件存在于当前章结尾处，但<THEN>事件未能构成独立的衔接事件，缺乏时间上的连贯性。剧情流程性(10/20): 跳转事件连接不够流畅，<IF>条件与当前情节的过渡不自然，未能充分体现情节之后的条件。事件合理性(12/20): 解药合成触发的能量波动激活米娅体内的伊芙琳意识，逻辑上存在一定合理性，但与背景设定和人物行为不完全一致。主体关联性(18/20): 触发条件由伊森的行为直接引发，符合主角关联性。逻辑完整性(10/20): <IF>条件描述不够单一，包含事件描述，<THEN>事件未能独立于章节内容复述。", "eva_score_opt": 65}], "message_pairs": [], "episdoe_desc_brief": "米娅的觉醒: 在寻找解药的过程中，米娅逐渐恢复意识，并帮助伊森对抗贝克家族。"}, {"episode_id": 10, "pre_episode_id": [8], "episode_goal": "伊森·温特斯的主要目标是找到并解救米娅，同时揭开伊芙琳的真实身份并阻止她的计划。", "episode_scene": "伊森在贝克家族的庄园中寻找米娅，这个庄园位于路易斯安那州的偏远地区，环境阴森恐怖，充满了腐败和超自然的气息。庄园内充斥着被感染的生物和危险的陷阱，伊森必须在这个充满威胁的环境中找到米娅并揭开隐藏的秘密。", "episode_desc": "伊森·温特斯终于在庄园深处找到了米娅，她被困在一个阴暗的房间里。米娅的状态似乎有所好转，她的眼神中闪烁着一丝清醒。伊森试图解救她，但此时伊芙琳的最终形态出现，阻挡了他们的去路。伊森意识到伊芙琳的真实身份，她是一个实验产物，拥有强大的感染和控制能力。为了阻止伊芙琳的计划，伊森必须与她展开最后的对抗。他心中充满了对米娅的担忧和对伊芙琳的警惕，知道只有击败伊芙琳才能拯救米娅和自己。面对伊芙琳的强大力量，伊森毫不退缩，坚定地迎战，誓要结束这场噩梦。", "episode_chars": ["伊森·温特斯: 坚韧不拔，充满决心和勇气。伊森是一名普通的工程师，为了寻找失踪的妻子米娅而来到贝克家族的庄园。在面对超自然的恐怖和危险时，他表现出非凡的毅力和求生能力。", "米娅·温特斯: 神秘复杂，内心挣扎。米娅是伊森的妻子，曾在贝克家族庄园失踪。她被卷入一个超自然的阴谋中，精神状态不稳定，时而表现出敌意，时而渴望被解救。", "伊芙琳: 阴险狡诈，具有操控能力。伊芙琳是庄园内的核心威胁，拥有超自然的力量，可以控制和感染他人。她的真实身份和计划是伊森必须揭开的关键谜团。"], "extra_info": [], "triggers": [{"condition": "<IF>伊森在抵抗伊芙琳攻击时发现她颈部霉菌核心因过度使用能力产生裂痕 <THEN>霉菌核心裂痕导致伊芙琳短暂僵直，伊森趁机将米娅转移至相对安全区域并获取火焰喷射器，为最终对决创造战术优势", "next_episode": 12, "eva_reason_ori": "时间连贯性(10/20): <IF>中提到的识破伊芙琳的操控能力和找到她的弱点并未在当前plot结尾明确展现，导致时间点不够连贯。<THEN>中提到的最终对决虽然符合时间顺序，但缺乏独立的衔接事件。剧情流程性(15/20): 跳转事件的连接较为流畅，但<IF>中的识破和找到弱点的过程缺乏在当前情节中的铺垫，导致流程性稍显不足。事件合理性(18/20): 伊森识破伊芙琳的能力并找到弱点符合逻辑，与故事背景和人物行为一致。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(10/20): <IF>包含多个条件（识破能力和找到弱点），不够单一且具体，<THEN>过于概括，缺乏独立事件。", "eva_score_ori": 73, "eva_opt_ori": "原<IF>包含双重条件（识破能力+找到弱点）且未在当前情节结尾体现具体触发动作，<THEN>复述下章核心内容导致衔接断裂。需将触发条件聚焦于主角当前章结尾已启动的关键动作：伊森在与伊芙琳初次对抗时发现其核心弱点（如霉菌核心暴露），该动作既承接当前章战斗开端，又直接引发后续战略调整。", "old_con": "<IF> **伊森成功识破伊芙琳的操控能力，并找到她的弱点，从而揭开她的真实身份，阻止她的计划** <THEN> **伊森在与伊芙琳的最终对决中利用这一弱点成功击败她，解救米娅，并为逃离庄园创造机会，最终得以与米娅一同逃出生天，等待救援人员的到来，结束这场噩梦**", "eva_reason_opt": "时间连贯性(15/20): <IF>存在于当前章结尾处，但其描述的裂痕并未在当前情节中得到铺垫，影响了时间连贯性。<THEN>衔接事件相对独立，但缺乏承上启下的过渡。剧情流程性(18/20): 跳转事件连接较为流畅自然，<IF>条件在当前情节之后发生，符合剧情流程。事件合理性(15/20): 霉菌核心裂痕的出现和伊森的反应合理，但缺乏前期铺垫，使得事件显得有些突兀。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合角色特性。逻辑完整性(17/20): <IF>条件单一且可验证，但缺乏前期铺垫。<THEN>包含独立事件，但描述略显冗长。", "eva_score_opt": 85}], "message_pairs": [], "episdoe_desc_brief": "拯救米娅: 伊森找到米娅并试图解救她，同时必须面对伊芙琳的最终形态，揭开她的真实身份并阻止她的计划。"}, {"episode_id": 11, "pre_episode_id": [9], "episode_goal": "伊森·温特斯的主要目标是通过米娅的牺牲来削弱伊芙琳的力量，从而找到机会彻底击败伊芙琳。", "episode_scene": "伊森在一个被感染和扭曲的环境中，面对着伊芙琳带来的巨大威胁。此时的背景是一个充满恐怖和绝望的场景，时间接近故事的高潮部分，伊森必须在这个充满危险的环境中找到解决问题的方法。", "episode_desc": "米娅意识到伊芙琳的威胁，决心牺牲自己来帮助伊森。她知道伊芙琳的力量源于对她的控制，因此米娅毅然决然地选择与伊芙琳对抗，以便给伊森创造机会。她用尽全力压制体内的感染，努力保持清醒，向伊森传递最后的信息。米娅用坚定的目光望着伊森，示意他必须继续前行，完成他们未竟的使命。伊森心中充满痛苦与不舍，但他明白米娅的牺牲是为了让他有机会击败伊芙琳。他含泪告别米娅，心中燃起复仇的火焰，决心不辜负她的期望，继续向前，迎接最终的对决。", "episode_chars": ["伊森·温特斯: 坚韧不拔且充满勇气。作为一个普通人，他被卷入了这场恐怖的事件中，为了拯救自己的妻子米娅和自己，他必须面对各种超自然的威胁。", "米娅·温特斯: 坚强且富有牺牲精神。她意识到伊芙琳的威胁，并决定以自己的牺牲来帮助伊森，展现出她对伊森的深厚感情和责任感。", "伊芙琳: 危险且不可预测。她是这场恐怖事件的核心威胁，具有操控和感染他人的能力，给伊森和米娅带来了巨大的挑战。"], "extra_info": [], "triggers": [{"condition": "<IF> **米娅意识到伊芙琳的威胁已达到无法控制的程度，并决定牺牲自己以削弱伊芙琳的力量，从而为伊森创造一个击败伊芙琳的机会。米娅的牺牲不仅是出于对伊森的深厚感情和责任感，也是为了保护更多无辜者免受伊芙琳的侵害。** <THEN> **米娅的牺牲成功削弱了伊芙琳的力量，使得伊森能够在失去米娅后独自面对伊芙琳。伊森在孤独与绝望中，凭借坚韧不拔的勇气，最终击败了伊芙琳并逃出庄园。然而，失去米娅的痛苦和心灵的重创将成为伊森接下来必须面对的挑战。**", "next_episode": 13, "eva_reason_ori": "时间连贯性(15/20): <IF>部分描述了米娅意识到威胁并决定牺牲自己，但没有明确的时间点延展到<THEN>部分，导致时间连贯性不足。剧情流程性(18/20): 整体流程较为自然，但<IF>部分的描述稍显冗长，影响了流畅性。事件合理性(20/20): 米娅的牺牲符合逻辑，与故事背景和人物行为一致。主体关联性(20/20): 触发条件由伊森的情感和行动间接引发，符合要求。逻辑完整性(15/20): <IF>部分包含多个条件和情感描述，而非单一可验证条件，<THEN>部分也包含了过多的事件复述，影响了逻辑的简洁性。", "eva_score_ori": 88}, {"condition": "<IF>伊森在米娅的遗体旁发现她刻意留下的感染抑制装置，装置表面残留着米娅最后刻下的血清合成公式 <THEN>伊森根据公式指引前往庄园实验室，在实验日志中发现伊芙琳的神经链接存在周期性衰减规律，该发现将直接影响后续战斗策略的制定", "next_episode": 16, "eva_reason_ori": "时间连贯性(12/20): <IF>部分没有明确时间节点，米娅的牺牲与伊森的意识觉醒之间缺乏直接的时间衔接，导致跳转事件的时间连贯性不足。剧情流程性(15/20): 虽然情感上的转变自然，但从米娅的牺牲到伊森找到对抗方法的逻辑链条不够清晰，缺乏具体的过渡步骤。事件合理性(16/20): 伊森的觉醒与米娅的牺牲相符，但找到对抗方法的过程缺乏详细描述，显得不够合理。主体关联性(18/20): 伊森的行为直接受到米娅的影响，符合主体关联性。逻辑完整性(14/20): <IF>部分包含了多个条件和情感描述，缺乏单一可验证条件，<THEN>部分则包含了多个事件，未能独立于章节内容。", "eva_score_ori": 75, "eva_opt_ori": "原<IF>包含多重情感觉醒和抽象精神力量描述，缺乏主角可验证的具体行为触发点。原<THEN>直接跨越到战斗结果，与下章谜题探索过程脱节。应聚焦伊森获取关键对抗手段的触发点：1.将触发条件具象化为收集米娅遗留物(直接关联当前章结尾告别动作)；2.衔接事件限定为获得破解操控的核心线索(对应下章解谜阶段)", "old_con": "<IF> **伊森在米娅牺牲后，意识到米娅的牺牲不仅是为了削弱伊芙琳的力量，更是为了唤醒他内心深处的勇气和决心。伊森感受到米娅的精神力量在他心中激荡，促使他不再仅仅为了生存而战，而是为了实现米娅的愿望，彻底击败伊芙琳。** <THEN> **伊森在这种新的精神力量的驱动下，找到了一种方法可以有效地对抗伊芙琳的操控能力。他利用这个突破口，成功地削弱了伊芙琳的防御，为最终的对决创造了条件。伊森带着米娅的希望和信念，坚定地走向与伊芙琳的最后对抗，并在最终战胜她后，带着米娅的精神力量逃出庄园。**", "eva_reason_opt": "时间连贯性(12/20): <IF>事件发生在米娅的遗体旁，但没有明确的时间延续性，缺乏对时间点的具体描述。剧情流程性(15/20): 从发现装置到前往实验室的过渡较为自然，但缺乏对伊森心理变化的详细刻画。事件合理性(16/20): 装置和公式的发现符合故事背景，但装置的存在显得过于便利，削弱了紧张感。主体关联性(18/20): 伊森的行动直接由米娅的遗留物引发，符合角色动机。逻辑完整性(14/20): <IF>条件包含了事件描述，未完全独立于事件本身；<THEN>事件较为独立，但缺乏对后续策略影响的具体说明。", "eva_score_opt": 75}], "message_pairs": [], "episdoe_desc_brief": "米娅的牺牲: 米娅意识到伊芙琳的威胁，选择牺牲自己来帮助伊森击败伊芙琳。"}, {"episode_id": 12, "pre_episode_id": [10], "episode_goal": "伊森·温特斯的主要目标是击败伊芙琳，解救米娅并逃离庄园，结束这场噩梦。", "episode_scene": "伊森在一个被感染和腐化的庄园中展开行动，这个庄园位于路易斯安那州的偏远地区。庄园被一种神秘的生化力量所控制，环境阴森恐怖，充满了未知的危险和敌意。时间上，伊森正处于与伊芙琳的最终对决前夕，必须在这个充满威胁的环境中找到生存和逃脱的途径。", "episode_desc": "伊森·温特斯在庄园深处与伊芙琳展开了最后的对决。伊芙琳的力量异常强大，她试图用幻觉和精神控制扰乱伊森的心智。然而，伊森凭借坚定的意志和对米娅的爱，抵抗住了伊芙琳的攻击。他利用庄园中找到的武器和药剂，逐步削弱伊芙琳的能力。经过一番激烈的战斗，伊森终于成功击败了伊芙琳，解除了她对贝克家族和米娅的控制。随着伊芙琳的消亡，庄园的阴霾逐渐散去，米娅恢复了神智。伊森带着米娅逃离了庄园，迎来了救援人员的到来，结束了这场噩梦般的经历。伊森和米娅在救援人员的帮助下，终于得以重获自由，离开了这个充满恐怖与绝望的地方。", "episode_chars": ["伊森·温特斯: 坚韧不拔，勇敢且富有求生意志。作为一名普通人，他被卷入了这个恐怖的事件中，为了拯救妻子米娅，他必须面对各种超自然的威胁和恐怖的敌人。", "米娅·温特斯: 复杂且神秘，曾被伊芙琳控制。她是伊森的妻子，曾在庄园中失踪多年，现被伊森解救后处于恢复状态，但仍然受到过去经历的影响。", "伊芙琳: 邪恶且具有操控能力的生化武器。她是庄园中恐怖事件的核心，能够控制和腐化周围的人和环境，对伊森和米娅构成极大的威胁。"], "extra_info": [], "triggers": [{"condition": "<IF>伊森在伊芙琳本体溃散后，发现菌核仍在释放感染孢子 <THEN>伊森用最后的高爆弹引爆菌核引发建筑坍塌，冲击波将二人震出主宅区域", "next_episode": 14, "eva_reason_ori": "时间连贯性(10/20): <IF>部分未明确出现在当前章结尾的时间点，缺乏明确的时间衔接。<THEN>部分虽然描述了事件的结果，但未能有效独立于下章开篇。剧情流程性(15/20): 跳转事件连接较为流畅，但<IF>条件在当前情节中未能充分达成，存在一定的跳跃性。事件合理性(18/20): 跳转事件基本合理，与故事背景和人物行为一致。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合角色设定。逻辑完整性(10/20): <IF>条件较为模糊，未能单一可验证，<THEN>部分包含过多事件描述，未能独立于章节内容。", "eva_score_ori": 73, "eva_opt_ori": "原<IF>使用主观意识判断导致条件不可验证，且与当前章结尾伊芙琳已被击败的情节冲突。改为基于主角战斗后的具体动作，聚焦触发逃离阶段的关键行为。原<THEN>复述章节内容且包含过多结果事件，调整为聚焦伊芙琳残留能量引发的次生危机，作为衔接逃离与救援的独立事件。", "old_con": "<IF> **伊森意识到必须彻底摧毁伊芙琳才能确保米娅的安全，并结束庄园的威胁** <THEN> **伊森在与伊芙琳的最终对决中，利用从庄园中获取的资源和信息，成功击败了伊芙琳。随着伊芙琳的消亡，庄园的腐化力量逐渐消退，伊森得以解救米娅并带她逃离庄园。在逃出庄园后，他们被及时赶到的救援人员接走，终于结束了这场噩梦，进入下一阶段的平静生活**", "eva_reason_opt": "时间连贯性(10/20): <IF>条件在当前章结尾没有明确提及菌核的存在，导致时间点的延展性不足。<THEN>事件的独立性较好，但与下章开篇的衔接不够自然。剧情流程性(15/20): 跳转事件的连接较为流畅，但<IF>条件在当前情节中没有充分铺垫，显得有些突兀。事件合理性(18/20): 跳转事件符合逻辑，伊森的行为与故事背景和人物风格一致。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(15/20): <IF>条件不够单一，涉及菌核和孢子的描述，复杂化了条件。<THEN>事件描述清晰，符合要求。", "eva_score_opt": 78}], "message_pairs": [], "episdoe_desc_brief": "逃出生天: 伊森成功击败伊芙琳，解救米娅并逃离庄园，最终被救援人员接走，结束了这场噩梦。"}, {"episode_id": 13, "pre_episode_id": [11], "episode_goal": "伊森·温特斯的主要目标是独自面对并击败伊芙琳，努力从庄园中逃脱。", "episode_scene": "伊森身处贝克家族的庄园，这是一座位于美国路易斯安那州偏远地区的破旧庄园。庄园被一种神秘的生化力量所笼罩，环境阴森恐怖，充满了危险和未知。时间接近故事的尾声，伊森在失去米娅后，孤身一人准备迎接最终的挑战。", "episode_desc": "伊森在失去米娅后，独自面对伊芙琳。他心中充满悲痛，却也因米娅的牺牲而燃起复仇的火焰。庄园内阴森的环境让他感到无比孤独，但他知道必须击败伊芙琳才能完成米娅的遗愿。伊芙琳的幻影在他周围徘徊，试图动摇他的意志。伊森紧握手中的武器，坚定地向伊芙琳发起攻击。经过一番激烈的对抗，伊森终于找到了伊芙琳的弱点，并成功击败了她。随着伊芙琳的消失，庄园也开始崩溃。伊森在废墟中艰难地寻找出路，最终逃出生天。然而，尽管身体得以逃脱，伊森的心灵却因失去米娅而受到重创，留下了难以愈合的伤痕。", "episode_chars": ["伊森·温特斯: 坚韧且执着，普通的工程师，因寻找失踪的妻子米娅而卷入了这场恐怖事件。在失去米娅后，他心灵受到重创，但仍然坚定地面对即将到来的挑战。", "伊芙琳: 外表是一个小女孩，实则是一个具有强大精神控制能力的生化武器。她性格扭曲，渴望家庭和亲情，但其行为极具破坏性。在当前情节中，她是伊森必须面对的最终敌人。"], "extra_info": [], "triggers": [{"condition": "<IF> **伊森意识到他必须独自面对并击败伊芙琳，以结束她对庄园的控制并为米娅的失去复仇，这成为他内心坚定的目标** <THEN> **伊森在与伊芙琳的最终对决中，凭借他的坚韧和执着，成功击败了她，从而解除庄园的威胁。然而，这场胜利并未带来内心的平静，反而让他更加感受到失去米娅的痛苦和孤独，心灵受到重创。尽管如此，他仍然设法逃出庄园，面对一个充满不确定性的未来，推动剧情进入下一个阶段**", "next_episode": 15, "eva_reason_ori": "时间连贯性(15/20): <IF>部分存在于当前章结尾处的时间点，但<THEN>部分未能完全独立于下章开篇，缺乏明确的时间过渡。剧情流程性(15/20): 跳转事件连接不够流畅自然，<IF>条件的达成与<THEN>事件的发生之间缺乏明显的因果关系。事件合理性(18/20): 跳转事件基本合理，符合逻辑，与故事背景和人物行为一致，但<THEN>部分的情感转变略显突兀。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合角色动机。逻辑完整性(15/20): <IF>条件较为复杂，缺乏单一可验证性，<THEN>事件包含过多情节复述，未能简化为独立事件。", "eva_score_ori": 83}], "message_pairs": [], "episdoe_desc_brief": "伊森的孤独: 在失去米娅后，伊森独自面对伊芙琳，最终击败她并逃出庄园，但心灵受到重创。"}, {"episode_id": 14, "pre_episode_id": [12], "episode_goal": "伊森的主要目标是击败伊芙琳，解救米娅并逃离庄园。", "episode_scene": "伊森在一个被感染的庄园中，时间接近夜晚，环境阴森恐怖，充满了被感染的生物和危险。庄园位于路易斯安那州的偏远地区，周围是茂密的森林和沼泽地，天气阴沉，气氛紧张。", "episode_desc": "伊森·温特斯深入贝克家族庄园的最深处，与伊芙琳展开了最后的对决。伊芙琳利用幻觉和精神控制试图扰乱伊森的心智，制造各种恐怖的幻象，试图让伊森屈服。然而，伊森凭借对妻子米娅的爱和坚定的意志，抵抗住了这些精神攻击。他在庄园中搜寻到了一些关键的武器和药剂，这些物品帮助他逐步削弱了伊芙琳的能力。在一场激烈的战斗中，伊森利用手中的武器与伊芙琳展开殊死搏斗，最终成功击败了她，解除了她对贝克家族和米娅的控制。随着伊芙琳的消亡，庄园的阴霾逐渐散去，米娅恢复了神智，伊森带着米娅逃离了庄园。", "episode_chars": ["伊森·温特斯: 坚韧不拔，勇敢且充满求生欲望。此时他正在努力寻找妻子米娅，并试图从这个被感染的庄园中逃脱。他面对着巨大的危险，但始终保持冷静和决心。", "米娅·温特斯: 复杂且神秘，曾被感染，性格在温柔和暴力之间摇摆不定。她是伊森的妻子，目前被困在庄园中，处于被感染的状态，时而清醒，时而受感染控制。", "伊芙琳: 邪恶且具有操控能力的生物，外表是一个小女孩。她是庄园感染的源头，具有强大的精神控制能力，能够操控被感染者的行为。"], "extra_info": [], "triggers": [{"condition": "<IF>伊森带着米娅逃离庄园时发现她瞳孔泛起菌丝微光 <THEN>伊森意识到感染残留，折返寻找根源时遭遇时空扭曲", "next_episode": -1, "eva_reason_ori": "时间连贯性(10/20): 当前<IF>击败伊芙琳的时间点与下一个plot的开篇不一致，存在时间断层，未能有效衔接。剧情流程性(10/20): 跳转事件缺乏自然过渡，伊森击败伊芙琳后直接迎来救援人员的到来显得突兀，缺乏过渡情节。事件合理性(15/20): 救援人员的到来在故事背景中未得到充分铺垫，显得不够合理。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(15/20): <IF>条件单一且可验证，但<THEN>部分包含了较多事件描述，削弱了独立性。", "eva_score_ori": 70, "eva_opt_ori": "原跳转事件与后续剧情存在根本矛盾：当前章结局已明确伊芙琳被击败且米娅存活，但下章开篇却呈现米娅死亡且伊芙琳复活状态。改进需建立时间循环/幻觉嵌套结构，通过米娅的异常征兆暗示精神控制未被完全清除，既保持恐怖生存风格又解决时间断层问题", "old_con": "<IF>击败伊芙琳 <THEN>伊森和米娅在庄园外迎来了救援人员的到来。两人终于得以重获自由，离开了这个充满恐怖与绝望的地方。在救援直升机上，伊森紧紧握住米娅的手，虽然身体疲惫不堪，但心中充满了对未来的希望。然而，伊森的眼神中仍然流露出一丝不安，仿佛预示着这场噩梦并未完全结束。", "eva_reason_opt": "时间连贯性(10/20): <IF>事件发生在逃离时，时间点不够明确且与下个plot的独立性不足。剧情流程性(10/20): 跳转事件的流畅性欠佳，伊森的折返与时空扭曲的连接显得突兀。事件合理性(15/20): 伊森发现米娅的感染残留是合理的，但时空扭曲缺乏背景支持。主体关联性(15/20): 触发条件由伊森的观察引发，但与其行为的直接关联性不强。逻辑完整性(10/20): <IF>条件不够单一明确，<THEN>事件描述过于复杂，缺乏独立性。", "eva_score_opt": 60}], "message_pairs": [], "episdoe_desc_brief": "噩梦终结: 伊森成功击败伊芙琳，解救米娅并逃离庄园，最终被救援人员接走，结束了这场噩梦。"}, {"episode_id": 15, "pre_episode_id": [13], "episode_goal": "伊森的主要目标是独自面对并击败伊芙琳，努力从恐怖的环境中逃出生天。", "episode_scene": "伊森在失去米娅后，独自一人在贝克家族庄园的地下实验室中。这个实验室隐藏在路易斯安那州的偏远地区，周围环境阴森恐怖，充满了未知的危险和敌意。时间是夜晚，整个庄园被黑暗笼罩，只有微弱的灯光和阴影在墙壁上摇曳。", "episode_desc": "伊森·温特斯在贝克家族庄园的废墟中独自前行，心中充满了失去米娅的痛苦和对伊芙琳的仇恨。庄园的阴影似乎在无声地嘲笑他的孤独，但伊森知道，只有击败伊芙琳才能完成米娅的遗愿。他紧握武器，面对伊芙琳的幻影毫不退缩。伊芙琳试图用幻象扰乱他的心智，但伊森凭借坚定的意志，逐渐找到了她的弱点。经过一场激烈的对抗，伊森终于成功击败了伊芙琳。随着她的消失，庄园开始崩溃。伊森在废墟中艰难地寻找出路。", "episode_chars": ["伊森·温特斯: 坚韧不拔，充满勇气和决心。此时他已经经历了重重磨难，失去了妻子米娅，但仍然坚持不懈地追求真相和生存的希望。在面对伊芙琳的威胁时，他表现出极大的勇气和毅力。", "伊芙琳: 阴险狡诈，具有操控和操纵他人的能力。她是一个神秘而危险的存在，能够影响他人的心智，并对伊森构成了巨大的威胁。她是伊森在庄园中必须面对的最终挑战。"], "extra_info": [], "triggers": [{"condition": "<IF>成功击败伊芙琳 <THEN>庄园的崩溃加速，伊森在废墟中艰难地寻找出路，最终逃出生天。然而，尽管身体得以逃脱，伊森的心灵却因失去米娅而受到重创，未来充满不确定性。伊森站在庄园外的空地上，望着逐渐沉入黑暗的废墟，心中充满了对未来的迷茫和对过去的悔恨。远处传来警笛声，似乎预示着新的开始，但伊森知道，心灵的伤口并不会因此愈合。", "next_episode": -1, "eva_reason_ori": "时间连贯性(15/20): <IF>成功击败伊芙琳与当前章节结尾的时间点一致，但<THEN>部分的庄园崩溃加速与伊森逃出生天的描述略显冗长，未能紧凑衔接。剧情流程性(18/20): 整体流程较为自然，伊森的逃脱与心灵创伤的描述顺畅，但警笛声的出现稍显突兀。事件合理性(17/20): 庄园崩溃与伊森的逃脱符合逻辑，但心灵创伤的描写与故事背景稍显重复。主体关联性(20/20): 伊森的行为直接引发了庄园的崩溃和后续事件。逻辑完整性(15/20): <IF>条件明确，但<THEN>部分包含了过多的事件描述，削弱了独立性。", "eva_score_ori": 85}], "message_pairs": [], "episdoe_desc_brief": "孤独的胜利: 伊森在失去米娅后独自击败伊芙琳，虽然逃出生天，但心灵受到重创，未来充满不确定性。"}, {"episode_id": 16, "pre_episode_id": [11], "episode_goal": "伊森·温特斯的主要目标是逃离庄园，并在此过程中寻求拯救米娅的机会。", "episode_scene": "在路易斯安那州的一个偏远庄园中，夜幕笼罩下的庄园充满了恐怖和神秘。伊森在寻找失踪的妻子米娅的过程中，深入这个被诅咒的地方，面对着各种超自然现象和危险生物的威胁。", "episode_desc": "伊森·温特斯在米娅的帮助下，深入贝克家族庄园的深处，面对最终的敌人伊芙琳。米娅用尽全力压制体内的感染，保持清醒，为伊森创造机会。伊森在庄园中穿梭，解开各种谜题，收集必要的资源和武器，最终与伊芙琳展开激烈的对决。在对战过程中，伊森需要躲避伊芙琳的攻击，同时寻找她的弱点进行反击。随着战斗的进行，伊森逐渐揭开伊芙琳的真实身份，并意识到她的操控能力来源于她体内的特殊感染源。", "episode_chars": ["伊森·温特斯: 坚韧且富有决心。在寻找妻子米娅的过程中，他展现出极大的勇气和毅力，面对恐怖的环境和敌人毫不退缩。", "米娅·温特斯: 内心充满矛盾和挣扎。她曾被感染并被迫做出可怕的事情，但在最后关头，她选择帮助伊森，展现出对丈夫的深切爱意和自我救赎的决心。", "伊芙琳: 具有操控能力的生物，外表为一个小女孩。她是庄园中一切恐怖事件的源头，性格扭曲且危险，渴望家庭和控制他人。"], "extra_info": [], "triggers": [{"condition": "<IF>伊森成功击败伊芙琳 <THEN>伊森在击败伊芙琳后，庄园开始崩溃。他带着米娅的希望，艰难地逃出庄园。尽管米娅已经不在，但她的勇敢和爱将永远伴随伊森。伊森站在庄园外，望着燃烧的废墟，心中充满对米娅的怀念和对未来的坚定信念。", "next_episode": -1, "eva_reason_ori": "时间连贯性(15/20): 虽然伊森击败伊芙琳后庄园开始崩溃是一个合理的时间延展，但缺乏对时间点的明确过渡描述，导致衔接不够清晰。剧情流程性(18/20): 整体跳转事件流畅自然，但伊森在击败伊芙琳后直接进入逃亡阶段，缺乏对战后心理状态的过渡描写。事件合理性(17/20): 庄园崩溃符合逻辑，但伊森的心理状态变化过于迅速，未充分体现恐怖生存和心理惊悚的风格。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合角色设定。逻辑完整性(16/20): <IF>条件明确，但<THEN>部分包含了过多的情感描写，影响了独立事件的呈现。", "eva_score_ori": 86}], "message_pairs": [], "episdoe_desc_brief": "米娅的救赎: 米娅在最后时刻帮助伊森击败伊芙琳，虽然自己牺牲，但伊森带着她的希望逃出庄园。"}]}

# %%
import jsonlines
import json
path = '/Users/destinyw/code/ai-story-data-generation/storyline_generator/story_framework_data/story_gen_03_11.jsonl'
ans = []
ans = []  # 初始化一个空列表
with jsonlines.open(path) as f:  # 打开 JSON Lines 文件
    for obj in f:  # 逐行迭代，每一行是一个 JSON 对象
        ans.append(obj)  # 将 JSON 对象添加到列表中
print(json.dumps(ans[0],indent=2,ensure_ascii=False))
# Out:
# {
#   "Settings": {
#     "story_id": "",
#     "story_name": "生化危机7(Resident Evil 7)",
#     "story_style": [
#       "恐怖生存",
#       "心理惊悚",
#       "阴森诡异",
#       "紧张刺激",
#       "黑暗神秘",
#       "家庭悲剧",
#       "超自然现象"
#     ],
#     "leading_role": "伊森·温特斯",
#     "story_desc": "故事发生在2017年，美国路易斯安那州的一个偏僻农场，伊森·温特斯收到了一段来自失踪三年的妻子米娅的神秘录像，指引他前往贝克家族的庄园。贝克家族是一个被感染的家庭，他们的行为变得极其暴力和疯狂。伊森在寻找妻子的过程中，逐渐揭开了庄园背后的恐怖秘密。",
#     "story_goal": "伊森的主要目标是找到并拯救他的妻子米娅，同时揭开贝克家族庄园的秘密，并设法逃离这个充满危险的地方。在过程中，他需要面对被感染的贝克家族成员和其他恐怖的生物，解开谜题，并逐步了解事件的真相。",
#     "story_chars": {
#       "伊森·温特斯": "身份标签",
#       "米娅·温特斯": "身份标签",
#       "伊芙琳": "身份标签",
#       "杰克·贝克": "身份标签",
#       "玛格丽特·贝克": "身份标签",
#       "卢卡斯·贝克": "身份标签"
#     },
#     "storylines": [
#       "寻找米娅:伊森·温特斯收到失踪三年的妻子米娅的消息，前往路易斯安那州的贝克家族庄园寻找她。",
#       "逃离庄园:伊森在庄园中发现米娅被感染并攻击他，他被迫击败她并继续探索庄园寻找逃脱的方法。",
#       "对抗贝克家族:伊森遭遇贝克家族的成员，包括杰克、玛格丽特和卢卡斯，他们被感染并变得极其危险，伊森必须与他们战斗以求生存。",
#       "揭示真相:伊森发现感染的源头是一个名叫伊芙琳的小女孩，她具有控制人心的能力，贝克家族因她而变得疯狂。",
# ...

# %%
{
  "Settings": {
    "story_id": "",
    "story_name": "生化危机7(Resident Evil 7)",
    "story_style": [
      "恐怖生存",
      "心理惊悚",
      "阴森诡异",
      "紧张刺激",
      "黑暗神秘",
      "家庭悲剧",
      "超自然现象"
    ],
    "leading_role": "伊森·温特斯",
    "story_desc": "故事发生在2017年，美国路易斯安那州的一个偏僻农场，伊森·温特斯收到了一段来自失踪三年的妻子米娅的神秘录像，指引他前往贝克家族的庄园。贝克家族是一个被感染的家庭，他们的行为变得极其暴力和疯狂。伊森在寻找妻子的过程中，逐渐揭开了庄园背后的恐怖秘密。",
    "story_goal": "伊森的主要目标是找到并拯救他的妻子米娅，同时揭开贝克家族庄园的秘密，并设法逃离这个充满危险的地方。在过程中，他需要面对被感染的贝克家族成员和其他恐怖的生物，解开谜题，并逐步了解事件的真相。",
    "story_chars": {
      "伊森·温特斯": "身份标签",
      "米娅·温特斯": "身份标签",
      "伊芙琳": "身份标签",
      "杰克·贝克": "身份标签",
      "玛格丽特·贝克": "身份标签",
      "卢卡斯·贝克": "身份标签"
    },
    "storylines": [
      "寻找米娅:伊森·温特斯收到失踪三年的妻子米娅的消息，前往路易斯安那州的贝克家族庄园寻找她。",
      "逃离庄园:伊森在庄园中发现米娅被感染并攻击他，他被迫击败她并继续探索庄园寻找逃脱的方法。",
      "对抗贝克家族:伊森遭遇贝克家族的成员，包括杰克、玛格丽特和卢卡斯，他们被感染并变得极其危险，伊森必须与他们战斗以求生存。",
      "揭示真相:伊森发现感染的源头是一个名叫伊芙琳的小女孩，她具有控制人心的能力，贝克家族因她而变得疯狂。",
      "拯救米娅:伊森找到米娅并试图解救她，同时必须面对伊芙琳的最终形态，揭开她的真实身份并阻止她的计划。",
      "逃出生天:伊森成功击败伊芙琳，解救米娅并逃离庄园，最终被救援人员接走，结束了这场噩梦。"
    ],
    "story_info": {
      "epi_struct": "multi",
      "gen_end_num": 3,
      "pre_epi_node": {
        "1": [
          0
        ],
        "2": [
          1
        ],
        "3": [
          2
        ],
        "4": [
          3
        ],
        "5": [
          3
        ],
        "6": [
          4
        ],
        "7": [
          5
        ],
        "8": [
          6
        ],
        "9": [
          7
        ],
        "10": [
          8
        ],
        "11": [
          9
        ],
        "12": [
          10
        ],
        "13": [
          11
        ],
        "14": [
          12
        ],
        "15": [
          13
        ],
        "16": [
          11
        ]
      },
      "language": "中文",
      "sources ": "",
      "sources": "game"
    },
    "states": {
      "0": {
        "seq": [
          1,
          2,
          3,
          5,
          7,
          9,
          11,
          16
        ],
        "Eva_outline_ori_think": "基础结构(15/20): 故事大部分章节以伊森·温特斯的视角展开，核心目标明确且贯穿始终。然而，episode 11和episode 16存在重复事件，导致扣分。时间轴单向流动，没有倒叙或插叙。\n连贯性(18/20): 整体章节剧情较为连贯，相邻章节保持时间和逻辑连续性，非相邻章节通过伏笔和线索形成隐性关联。但episode 11和episode 16的重复内容略微影响整体连贯性。\n合理性(18/20): 整体剧情形成完整闭环，前后逻辑合理，事件发生自然，符合世界观和人物性格。重复事件在合理性上略有影响。\n完整性(17/20): 整体剧情完整，前期剧情对后期有影响，节奏大体合理。但episode 11和episode 16的重复使得部分剧情显得冗余。\n吸引性(19/20): 整体故事引人入胜，节奏合理，具有悬念和高潮。重复事件对吸引性影响较小。\n",
        "Eva_outline_ori_score": 87
      },
      "1": {
        "seq": [
          1,
          2,
          3,
          5,
          7,
          9,
          11,
          13,
          15
        ],
        "Eva_outline_ori_think": "基础结构(15/20): 主角伊森·温特斯的视角贯穿始终，核心目标明确。然而，episode 15与episode 13的内容几乎重复，导致事件重复性问题，扣5分。连贯性(18/20): 整体剧情连贯，相邻章节保持时间和逻辑连续性，但episode 15与episode 13的重复导致相邻章节重叠，扣2分。合理性(18/20): 整体剧情形成闭环，逻辑合理，符合世界观和人物性格，但重复事件影响合理性，扣2分。完整性(15/20): 整体剧情完整，前期剧情对后期有影响，但episode 15的重复使得结局显得拖沓，扣5分。吸引性(18/20): 整体故事引人入胜，节奏合理，有悬念和高潮，但重复事件削弱了部分吸引力，扣2分。",
        "Eva_outline_ori_score": 84,
        "Eva_outline_refine_think": "基础结构(15/20): 主角伊森的视角始终贯穿，核心目标明确。但episode 13和15的事件重复，扣5分。时间轴单向流动。连贯性(18/20): 整体剧情连贯，相邻章节逻辑连续，非相邻章节通过伏笔关联。但episode 13和15内容重复，扣2分。合理性(20/20): 整体形成闭环，剧情逻辑合理，符合世界观和人物性格。完整性(18/20): 整体完整，前期对后期有影响，但episode 11米娅的牺牲有些突兀，扣2分。吸引性(20/20): 故事引人入胜，节奏合理，有悬念和高潮。",
        "Eva_outline_refine_score": 91
      },
      "2": {
        "seq": [
          1,
          2,
          3,
          4,
          6,
          8,
          10,
          12,
          14
        ],
        "Eva_outline_ori_think": "基础结构(15/20): 主角视角和核心目标明确，但episode 14与episode 12重复，扣5分。时间轴单向流动。连贯性(15/20): 整体连贯性较好，但episode 12与episode 14内容重复，扣5分。合理性(18/20): 整体逻辑合理，符合世界观，但重复事件导致轻微扣分。完整性(15/20): 故事基本完整，但重复事件影响节奏，扣5分。吸引性(18/20): 故事有趣，节奏合理，有悬念和高潮，但重复事件略微影响吸引力，扣2分。",
        "Eva_outline_ori_score": 81,
        "Eva_outline_refine_think": "基础结构(15/20): 主角伊森·温特斯的视角和核心目标明确，但episode 12和episode 14内容重复，导致扣分。时间轴基本单向流动，没有倒叙或插叙。\n连贯性(18/20): 整体章节剧情连贯，相邻章节保持时间和逻辑连续性，但episode 12和episode 14内容重复，影响了非相邻章节的隐性关联。\n合理性(18/20): 整体形成闭环，前后剧情逻辑合理，但重复的内容在合理性上略显不足。\n完整性(15/20): 整体剧情较完整，但episode 12和episode 14的重复使得结局显得不够紧凑，影响了节奏。\n吸引性(17/20): 故事整体有趣，引人入胜，节奏合理，存在悬念和高潮，但重复内容略微削弱了吸引力。\n",
        "Eva_outline_refine_score": 83
      }
    },
    "gen_parameter": {
      "data_folder": "storyline_generator/story_framework_data",
      "combine_episode_num": 1,
      "seg_main_episode_num": 10,
      "use_language": 0,
      "story_branch_num": 2,
      "if_single_episode": false,
      "if_role_known": false,
      "stroy_source": "game",
      "use_rag_know": 0
    }
  },
  "Episodes": [
    {
      "episode_id": 1,
      "pre_episode_id": [
        0
      ],
      "episode_goal": "伊森·温特斯的主要目标是找到失踪三年的妻子米娅，并了解她失踪的真相。",
      "episode_scene": "伊森·温特斯收到一条来自失踪三年的妻子米娅的神秘消息，指引他前往美国路易斯安那州的贝克家族庄园。这个庄园位于偏远的乡村地区，周围环境阴森恐怖，充满了未知的危险和谜团。伊森在夜幕降临时抵达庄园，准备展开他的寻找之旅。",
      "episode_desc": "伊森·温特斯接到一封神秘的邮件，发件人自称是他失踪三年的妻子米娅。邮件中附有一个地址，位于路易斯安那州的贝克家族庄园。伊森心中充满疑惑和希望，决定亲自前往庄园寻找米娅的下落。驱车驶入庄园附近，阴森的环境和破败的建筑让他感到不安，但他坚定地走向庄园，准备面对未知的挑战。",
      "episode_chars": [
        "伊森·温特斯: 坚韧且富有决心。作为一名普通的白领，他因妻子的失踪而心力交瘁，但在收到米娅的消息后，他毫不犹豫地踏上了寻找她的旅程。伊森此时充满了希望和不安，渴望解开妻子失踪的谜团。",
        "米娅·温特斯: 神秘而复杂。她在三年前突然失踪，留下了一个无法解释的空白。米娅的消息让人感到困惑，她的现状和动机尚不明确，成为伊森此行的核心谜题。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF> **伊森·温特斯在贝克家族庄园外发现了一些异常迹象，这些迹象暗示米娅可能在庄园内，并且处于危险之中。伊森的内心驱动力是对妻子的深切思念和渴望解开她失踪的谜团，这促使他不顾个人安危，决定进入庄园。** <THEN> **伊森进入庄园后，发现环境阴森恐怖，并找到一段米娅留下的录像。录像中米娅的求救信息进一步确认她被困在地下室，这使得伊森的目标更加明确，推动他继续深入探索庄园，寻找妻子的下落。**",
          "next_episode": 2,
          "eva_reason_ori": "时间连贯性(15/20): <IF>部分提到伊森在庄园外发现异常迹象，但没有明确的时间点延展，导致时间连贯性稍显不足。<THEN>部分在进入庄园后找到录像带，时间上较为连贯。扣分原因：<IF>缺乏明确的时间点延展。\n剧情流程性(18/20): 整体跳转事件较为流畅自然，伊森的驱动力和进入庄园后的发现形成了合理的剧情连接。扣分原因：<IF>部分的异常迹象描述稍显模糊。\n事件合理性(17/20): 伊森因妻子的失踪而进入庄园符合逻辑，但<IF>部分的异常迹象未具体化，稍显不合理。扣分原因：异常迹象的合理性不足。\n主体关联性(20/20): 触发条件由伊森的行为直接引发，符合主体关联性。\n逻辑完整性(18/20): <IF>部分包含了多个条件而非单一可验证条件，影响逻辑完整性。<THEN>部分较为独立。扣分原因：<IF>条件过于复杂。\n",
          "eva_score_ori": 88
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "寻找米娅: 伊森·温特斯收到失踪三年的妻子米娅的消息，前往路易斯安那州的贝克家族庄园寻找她。"
    },
    {
      "episode_id": 2,
      "pre_episode_id": [
        1
      ],
      "episode_goal": "伊森的主要目标是进入庄园，寻找他的妻子米娅，并解开她失踪的谜团。",
      "episode_scene": "伊森·温特斯在收到一封来自失踪三年的妻子米娅的神秘信件后，来到路易斯安那州的一座偏僻庄园。庄园的环境阴森恐怖，四周弥漫着不祥的气息，时间是夜晚，四周寂静无声，给人一种压抑和不安的感觉。",
      "episode_desc": "伊森·温特斯推开贝克家族庄园的大门，迎面而来的腐朽气息和阴森的氛围让他不寒而栗。庄园内光线昏暗，墙壁斑驳，地板嘎吱作响，仿佛诉说着不为人知的秘密。他小心翼翼地探索着，试图找到任何有关米娅的线索。在一间破旧的房间里，他发现了一台老旧的录像机和一盘录像带。伊森插入录像带，屏幕上出现了米娅的身影。录像中的米娅神情憔悴，语气急促，暗示她被困在庄园的地下室。伊森心中一紧，意识到米娅可能正处于危险之中。他决心深入探索，寻找通往地下室的入口，救出自己的妻子。",
      "episode_chars": [
        "伊森·温特斯: 坚韧不拔，充满勇气和决心。为了寻找失踪的妻子，他不顾危险进入了这个神秘的庄园。他对米娅的爱和对真相的渴望驱使着他不断前行。",
        "米娅·温特斯: 神秘且复杂。她失踪多年后突然与伊森联系，暗示自己可能被困在庄园的地下室。她的现状不明，给人一种既熟悉又陌生的感觉。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF> **伊森在庄园中发现米娅留下的录像，录像中暗示她可能被困在地下室，这一信息激发了伊森强烈的求生欲望和对米娅的关切之情，促使他决定深入调查。** <THEN> **伊森根据录像中的线索，找到通往地下室的入口，并在地下室中发现被感染的米娅。她在短暂清醒后攻击伊森，迫使他做出艰难的选择：是击败米娅以自保，还是尝试控制她以拯救她。这个选择直接影响到伊森的下一步行动和情节的发展。**",
          "next_episode": 3,
          "eva_reason_ori": "时间连贯性(15/20): <IF>中提到的录像带发现和伊森的决心在当前章结尾处延展的时间点合理，但<THEN>中直接跳转到地下室，缺乏具体的时间过渡。剧情流程性(15/20): 跳转事件连接不够流畅，自录像带到地下室的过渡略显突兀，缺少中间的探索过程。事件合理性(18/20): 跳转事件基本符合逻辑，伊森的行为动机与故事背景一致，但对地下室入口的发现缺乏详细描述。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(15/20): <IF>条件较为复杂，包含了多个因素，如求生欲望和关切之情，建议简化为单一可验证条件。<THEN>部分包含了后续情节的复述，建议仅描述独立事件。",
          "eva_score_ori": 83
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "初入庄园: 伊森进入庄园，发现环境阴森恐怖，并找到一段米娅留下的录像，提示她可能被困在地下室。"
    },
    {
      "episode_id": 3,
      "pre_episode_id": [
        2
      ],
      "episode_goal": "伊森的主要目标是面对被感染的米娅，做出是否击败她或尝试控制她的选择，以便继续探索和解开背后的谜团。",
      "episode_scene": "伊森在贝克家族的庄园中探索时，进入了阴暗潮湿的地下室。这个地下室充满了腐烂和恐怖的气息，墙壁上布满了霉菌和血迹，四周弥漫着令人窒息的压迫感。在这里，伊森发现了被感染的米娅，并面临艰难的选择。",
      "episode_desc": "伊森·温特斯在贝克家族庄园的地下室中找到被感染的米娅。她的面容憔悴，眼神中透露出一丝清醒。伊森试图与她沟通，但米娅突然情绪失控，向他发起攻击。面对突如其来的危险，伊森心中挣扎不已。他必须在保护自己的同时，尝试唤醒米娅的理智。米娅的攻击愈发猛烈，伊森被迫做出艰难的选择：是击败眼前的米娅，还是冒险尝试控制她，以期恢复她的清醒。在这个充满绝望与希望的时刻，伊森的每一个决定都可能改变他们的命运。",
      "episode_chars": [
        "伊森·温特斯: 勇敢而坚韧，充满求生欲望和对妻子的深切关怀。此时他正努力寻找失踪的妻子米娅，并被迫面对各种恐怖和超自然的威胁。",
        "米娅·温特斯: 曾经温柔善良，但现在被感染后变得不稳定且具有攻击性。在短暂清醒时，她仍然表现出对伊森的爱和关心，但很快又被感染控制，变得极具威胁性。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF>伊森在压制米娅攻击时未能及时控制其暴走状态 <THEN>米娅倒地时体内溢出的霉菌引发地下室剧烈震动，暴露墙体隐藏的暗道入口",
          "next_episode": 4,
          "eva_reason_ori": "时间连贯性(12/20): <IF>部分描述了伊森意识到米娅短暂清醒的机会和失控的威胁，但在时间点的延展上不够明确，缺乏对具体时间节点的清晰描述。<THEN>部分虽然承接了伊森的决心，但未能独立于下章开篇的衔接事件。剧情流程性(15/20): 整体流程较为自然，但<IF>中伊森的选择过程略显仓促，缺乏对选择过程的详细刻画，使得跳转事件的流畅性稍有欠缺。事件合理性(16/20): 跳转事件在逻辑上基本合理，符合故事背景和人物行为，但伊森的选择似乎过于直接，缺乏对其内心挣扎的深入探讨。主体关联性(18/20): 触发条件由伊森的行为直接引发，符合主角的角色设定。逻辑完整性(14/20): <IF>部分包含多个条件和事件描述，显得不够单一和明确；<THEN>部分虽然包含独立事件，但与章节内容复述的界限不够清晰。",
          "eva_score_ori": 75,
          "eva_opt_ori": "原触发事件中<IF>同时包含心理抉择和物理动作，不符合单一可验证条件要求。根据评估结果，需聚焦于主角可验证的物理动作作为触发条件。将米娅最终失控作为触发点，既符合当前情节结尾延展的时间点，又能直接引发后续事件。<THEN>需要建立独立衔接事件而非复述下章内容，通过环境异变作为击败行为的直接后果，既保持恐怖生存风格，又形成自然过渡。",
          "old_con": "<IF> **伊森在地下室面对被感染的米娅时，意识到她的短暂清醒是他与妻子重新建立联系的唯一机会，但同时也感受到她再次失控的威胁迫在眉睫。伊森必须在保护自己的安全和对妻子的深切关怀之间做出艰难选择，最终决定击败米娅以确保自身的生存，并继续寻找解开感染谜团的方法。** <THEN> **伊森在痛苦中击败米娅后，意识到自己必须尽快找到逃离庄园的方法，同时也要揭开感染背后的真相，以便为米娅和自己寻求最终的救赎。他的决心和求生欲望驱使他继续探索庄园，面对接下来的未知威胁和挑战。**",
          "eva_reason_opt": "时间连贯性(10/20): <IF>的时间点不明确，未能有效承接当前章节结尾，<THEN>未能独立于下章开篇的事件。剧情流程性(15/20): 跳转事件存在一定的逻辑，但不够流畅自然，<IF>的条件在当前情节中不够明确。事件合理性(10/20): 霉菌引发地下室震动的设定缺乏合理性，与故事背景不完全一致。主体关联性(15/20): 触发条件与伊森的行为有一定关联，但不够直接。逻辑完整性(10/20): <IF>条件不够单一明确，<THEN>事件缺乏独立性。",
          "eva_score_opt": 60
        },
        {
          "condition": "<IF>伊森在被米娅压制时触碰到实验台遗留的镇定药剂注射器 <THEN>注射器内残余血清使米娅进入短暂休眠状态，其手腕浮现发光的霉菌纹路指向走廊方向",
          "next_episode": 5,
          "eva_reason_ori": "时间连贯性(10/20): <IF>中提到的意识到米娅的短暂清醒作为重新建立联系的机会，但这个意识并没有在当前章结尾明确发生，缺乏时间点的延展性。<THEN>中伊森的决定虽然是衔接事件，但没有独立于下章开篇。剧情流程性(15/20): 跳转事件的连接较为自然，但<IF>中的意识到米娅的清醒并没有在当前情节之后的明确条件。事件合理性(18/20): 伊森尝试控制米娅而不是击败她符合他的性格和故事背景。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(12/20): <IF>包含多个意识和动机，缺乏单一可验证条件，<THEN>包含的事件较多，未能独立于章节内容。",
          "eva_score_ori": 75,
          "eva_opt_ori": "原<IF>包含意识觉醒和心理动机等非行为要素，不符合单一可验证条件要求，且时间点未延展至当前情节之后。原<THEN>与下章开篇存在内容重叠，未形成独立衔接事件。改进后聚焦伊森在战斗中的具体行为触发控制结果，通过药剂注射建立与后续解药线索的因果链",
          "old_con": "<IF> **伊森在地下室面对被感染的米娅时，意识到她的短暂清醒不仅是重新建立联系的机会，也是揭示感染背后真相的关键线索。他感受到米娅内心深处仍然存在的善良和对他的爱，这促使他尝试控制她，而不是击败她。伊森的内心驱动力是对妻子的深切关怀和对解开感染谜团的渴望。** <THEN> **伊森成功控制住米娅的攻击，决定带她一起寻找解药。他意识到，米娅的清醒状态可能会提供关于感染的重要信息，这将帮助他们揭开谜团并找到治愈的方法。伊森的选择开启了他们共同面对庄园中隐藏的更深层次威胁的旅程。**",
          "eva_reason_opt": "时间连贯性(10/20): <IF>中提到的触碰注射器事件在当前plot中没有明确的时间点延展，且<THEN>的镇定效果与下章开篇的对抗不够连贯。剧情流程性(15/20): 虽然触碰注射器的事件可以在当前情节中达成，但其效果与下章的对抗情节衔接不够自然。事件合理性(10/20): 注射器的出现和作用缺乏足够的背景支持，镇定效果过于便利且与故事背景不符。主体关联性(15/20): 触发条件由伊森的行为引发，但缺乏足够的动机和背景支持。逻辑完整性(10/20): <IF>条件不够单一且具体，<THEN>包含的事件过于复杂，缺乏清晰的因果关系。",
          "eva_score_opt": 60
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "地下室的选择: 伊森在地下室找到被感染的米娅，她在短暂清醒后攻击伊森。伊森面临选择:击败米娅或尝试控制她。"
    },
    {
      "episode_id": 4,
      "pre_episode_id": [
        3
      ],
      "episode_goal": "伊森·温特斯的主要目标是寻找逃脱贝克家族庄园的方法，并继续探索庄园。",
      "episode_scene": "伊森·温特斯在寻找失踪的妻子米娅的过程中，来到美国路易斯安那州的一个偏远庄园。这个庄园属于贝克家族，庄园内充满了恐怖和神秘的氛围，环境阴森且充满危险。伊森在庄园中不断遭遇超自然的现象和敌对的家族成员，必须在这个充满未知的地方寻找生存和逃脱的途径。",
      "episode_desc": "伊森·温特斯在地下室与米娅的激烈对抗中，心中充满了痛苦和无奈。米娅的攻击毫不留情，伊森被迫在自卫与拯救之间做出艰难的抉择。最终，伊森忍痛击败了米娅，看到她倒下的瞬间，他的心仿佛被撕裂。尽管如此，他知道自己必须继续前行，寻找逃离这个恐怖庄园的方法。他擦去脸上的汗水，坚定地走出地下室，继续在阴暗的走廊中探索，希望能找到一条通往自由的出路。庄园内的每一个角落都充满了未知的危险，但伊森心中只有一个信念，那就是活着离开这里，并找出这一切背后的真相。",
      "episode_chars": [
        "伊森·温特斯: 坚韧且富有求生意志的普通人，因妻子米娅的失踪而来到贝克家族庄园。在面对恐怖和危险时展现出勇敢和决心，努力寻找妻子并逃离庄园。",
        "米娅·温特斯: 伊森的妻子，曾失踪多年，性格复杂，时而温柔时而暴力。她在庄园中被发现，但似乎受到了某种控制，行为变得不可预测，给伊森带来了极大的困扰和挑战。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF> **伊森在击败米娅后，意识到庄园内的威胁远不止于此，并发现了一些线索暗示贝克家族的成员是庄园中更大的威胁。他的求生意志和对妻子的责任感驱使他继续探索庄园，寻找逃脱的方法。** <THEN> **伊森深入庄园，遭遇贝克家族的成员杰克、玛格丽特和卢卡斯。他们的极端行为和对伊森的敌意迫使他不得不与他们对抗，以求生存并继续寻找逃脱的途径。**",
          "next_episode": 6,
          "eva_reason_ori": "时间连贯性(15/20): <IF>中提到伊森意识到庄园内的威胁并发现线索，这些内容在当前情节结尾并未明确展现，扣5分。<THEN>部分与下一情节开篇的衔接较为自然。\n剧情流程性(15/20): <IF>条件在当前情节之后可以达成，但缺乏明确的过渡细节，扣5分。\n事件合理性(18/20): 跳转事件总体合理，但<IF>中提到的线索发现没有具体描述，略显突兀，扣2分。\n主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。\n逻辑完整性(15/20): <IF>条件描述较为模糊，未能形成单一可验证条件，扣5分。<THEN>部分包含独立事件，符合要求。",
          "eva_score_ori": 83
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "击败米娅: 伊森被迫击败米娅，继续探索庄园寻找逃脱的方法。"
    },
    {
      "episode_id": 5,
      "pre_episode_id": [
        3
      ],
      "episode_goal": "伊森的主要目标是控制住米娅的攻击，并带她一起寻找解药，以便解决当前的困境。",
      "episode_scene": "伊森在一个被遗弃的庄园中，庄园位于路易斯安那州的一个偏远地区。时间是深夜，环境阴森恐怖，充满了未知的危险和谜团。庄园内部破败不堪，充满了腐朽的气息，四周寂静无声，偶尔传来令人毛骨悚然的声音。",
      "episode_desc": "伊森·温特斯在地下室与被感染的米娅展开激烈的对抗。米娅的攻击迅猛而疯狂，但伊森心中仍存有一丝希望，他相信自己的妻子仍在这具被感染的躯壳中。经过一番挣扎，伊森设法控制住米娅的攻击，暂时平息了她的狂暴状态。他小心翼翼地将她束缚住，避免她再次失控。米娅的眼神中闪烁着痛苦与挣扎，似乎在与体内的感染抗争。伊森心中明白，必须尽快找到解药，才能真正拯救米娅。他决定带上米娅，一同在庄园中寻找可能的解药线索。两人步履蹒跚地穿过阴暗的走廊，伊森紧握着米娅的手，誓言无论多么艰难，都要带她重返光明。",
      "episode_chars": [
        "伊森·温特斯: 坚韧不拔，勇敢且充满决心。他是一个普通的白领，因为收到失踪妻子米娅的消息而来到庄园。他在寻找米娅的过程中遭遇了许多危险，但始终坚持不懈，试图解救妻子并逃离险境。",
        "米娅·温特斯: 情绪不稳定，时而温柔时而狂暴。她是伊森的妻子，曾失踪多年，现被困在庄园中。米娅在被控制时会攻击伊森，但她内心仍然渴望被解救和恢复正常。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF>伊森确认米娅的束缚装置足以维持十分钟安全期后，将地下室出口作为优先行动方向 <THEN>两人穿过渗水的储藏间时，米娅被铁门锈蚀声刺激突然挣扎，导致伊森发现暗门后的化学试剂气味",
          "next_episode": 7,
          "eva_reason_ori": "时间连贯性(10/20): <IF>中提到的伊森安抚米娅和意识到危险的时间点与当前章节结尾的时间点不够明确，缺乏具体的时间过渡。<THEN>中的行动动机虽有，但缺乏独立的衔接事件。剧情流程性(15/20): 整体流程较为自然，但<IF>中的条件似乎过于复杂，包含了多个事件。事件合理性(18/20): 跳转事件与故事背景和人物行为基本一致，但米娅在短暂清醒中透露线索的合理性稍显勉强。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(12/20): <IF>包含多个条件和事件描述，而非单一可验证条件；<THEN>部分缺乏独立事件，更多是章节内容的延续。",
          "eva_score_ori": 75,
          "eva_opt_ori": "原<IF>存在多重条件堆砌(安抚/控制/恢复理智/意识危险)且时间锚点模糊，违反单一可验证原则。原<THEN>直接复现下章核心线索发现过程，缺乏独立衔接层。改进后以「行动决策」作为触发点，建立「环境移动」作为物理过渡层。",
          "old_con": "<IF> **伊森成功地安抚并暂时控制住米娅的攻击行为，使她恢复片刻的理智，意识到继续留在原地只会带来更大的危险。伊森的主要目标是确保米娅的安全，并带她一起寻找解药，以便解决当前的困境。** <THEN> **米娅在短暂的清醒中透露了关于庄园中可能藏有解药的线索，激发了伊森的希望和行动动力。伊森决定带着米娅深入庄园，寻找解药的具体位置，这一决定将他们引向庄园更深处的未知区域，开启了新的冒险和挑战。**",
          "eva_reason_opt": "时间连贯性(15/20): <IF>中提到的'十分钟安全期'没有在当前plot中明确提及，导致时间连贯性略显不足。剧情流程性(18/20): 从地下室到庄园的过渡较为自然，但<THEN>中米娅挣扎的原因和后续发现化学试剂的过程稍显突兀。事件合理性(16/20): 米娅因铁门锈蚀声而挣扎的设定有些勉强，虽然符合恐怖生存的风格，但与故事背景的紧张氛围不完全一致。主体关联性(20/20): 伊森的行为直接引发了事件的发生，符合要求。逻辑完整性(18/20): <IF>条件较为明确，但<THEN>中的事件描述稍显复杂，影响了逻辑的简洁性。",
          "eva_score_opt": 87
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "控制米娅: 伊森设法控制住米娅的攻击，决定带她一起寻找解药。"
    },
    {
      "episode_id": 6,
      "pre_episode_id": [
        4
      ],
      "episode_goal": "伊森·温特斯的核心目标是对抗并击败贝克家族的成员，以求在这片危险的环境中生存下来。",
      "episode_scene": "伊森·温特斯在寻找失踪的妻子米娅的过程中，来到了一处偏僻的路易斯安那州的农场。这片农场被茂密的森林包围，阴森恐怖，充满了腐朽和危险的气息。时间是夜晚，环境昏暗，四周静谧而令人不安，给人一种随时可能遭遇危险的紧迫感。",
      "episode_desc": "伊森·温特斯在庄园的走廊中继续前行，突然遭遇贝克家族的成员。杰克·贝克出现在他的面前，面目狰狞，毫无理智地向伊森发起攻击。伊森迅速反应，利用手中的武器与杰克展开激烈搏斗。尽管杰克力大无穷，但伊森凭借机智与勇气，勉强将其击退。随后，伊森继续探索，遇到了玛格丽特·贝克，她的身体被感染后变得极其怪异，操控着一群昆虫攻击伊森。伊森艰难地躲避着，寻找机会反击，最终成功将玛格丽特击败。就在他以为可以松一口气时，卢卡斯·贝克的陷阱又让他陷入新的危机。伊森小心翼翼地破解卢卡斯设置的机关，心中明白他必须保持警惕，才能在这个充满危险的庄园中生存下去。每一次与贝克家族的对抗都让伊森更加坚定，他知道只有击败这些被感染的敌人，才能找到逃出生天的希望。",
      "episode_chars": [
        "伊森·温特斯: 坚韧且富有求生本能的普通人。他在寻找妻子的过程中被卷入了贝克家族的恐怖事件中，必须依靠智慧和勇气来面对各种危险。",
        "杰克·贝克: 贝克家族的父亲，性格狂暴且具有攻击性。他被感染后变得极其危险，常常以暴力和恐怖的方式对待入侵者。",
        "玛格丽特·贝克: 贝克家族的母亲，性格阴险且狡诈。她被感染后具有操控昆虫的能力，常常利用环境来对付敌人。",
        "卢卡斯·贝克: 贝克家族的儿子，性格狡猾且具有恶作剧心理。他喜欢设置陷阱和谜题来折磨和戏弄他人。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF> **伊森在与贝克家族的对抗中逐渐意识到，单纯的武力对抗无法彻底解决问题，他需要寻找导致贝克家族疯狂的根源，以便从根本上解除威胁** <THEN> **伊森在一次与贝克家族成员的激烈交锋中，偶然发现了一些关于伊芙琳的线索，这些线索指向了感染的源头，促使他开始调查伊芙琳的真实身份和她的能力，从而引导剧情进入揭示真相的阶段**",
          "next_episode": 8,
          "eva_reason_ori": "时间连贯性(15/20): 当前<IF>中提到伊森意识到需要寻找根源，但没有明确的时间点或事件作为触发，缺乏具体的时间连贯性。剧情流程性(15/20): <IF>与<THEN>之间的连接较为模糊，伊森的意识转变与线索发现之间的自然过渡不够清晰。事件合理性(18/20): 伊森意识到需要寻找根源是合理的，但偶然发现线索的描述略显随意。主体关联性(20/20): <IF>明确由伊森的意识转变引发，符合主体关联性。逻辑完整性(15/20): <IF>条件描述较为笼统，不够具体，<THEN>事件描述较为完整，但缺乏明确的触发条件。",
          "eva_score_ori": 83
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "对抗贝克家族: 伊森遭遇贝克家族的成员，包括杰克、玛格丽特和卢卡斯，他们被感染并变得极其危险，伊森必须与他们战斗以求生存。"
    },
    {
      "episode_id": 7,
      "pre_episode_id": [
        5
      ],
      "episode_goal": "伊森的主要目标是找到解药，以治愈米娅并解除她身上的诅咒。",
      "episode_scene": "伊森和米娅在贝克家族的庄园中寻找解药的线索。这个庄园位于路易斯安那州的偏远地区，四周被沼泽地包围，环境阴森恐怖，充满了未知的危险和谜团。庄园内的建筑破旧不堪，充满了神秘和诡异的氛围。",
      "episode_desc": "伊森和米娅在庄园中继续寻找解药的线索。他们穿过一间又一间破败的房间，墙壁上斑驳的壁纸和地板上厚厚的灰尘无不昭示着这里的荒废。伊森小心翼翼地翻找每一个抽屉和柜子，试图找到任何可能的线索。米娅虽然被束缚，但她的眼神中透露出一丝清醒，偶尔会低声提醒伊森注意周围的动静。两人来到一间实验室，墙上挂满了复杂的化学公式和实验记录。伊森在一堆杂物中发现了一本发黄的笔记，里面详细记录了某种病毒的研究过程和可能的解药配方。尽管笔记的内容晦涩难懂，但伊森知道这可能是他们找到解药的关键。他们决定继续深入探索，希望能找到制作解药所需的材料和设备。",
      "episode_chars": [
        "伊森·温特斯: 坚韧不拔，勇敢且执着。为了拯救妻子米娅，他不顾自身安危深入险境。在寻找解药的过程中，他展现出强烈的求生意志和对妻子的深厚感情。",
        "米娅·温特斯: 复杂而神秘，内心深处充满挣扎。她被感染后性格变得不稳定，时而温柔时而暴躁。她对伊森的感情是真挚的，但被感染后常常无法控制自己的行为。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF>伊森根据笔记配方线索走向地下室培养舱提取菌株样本时 <THEN>菌株共鸣引发米娅颅内寄生体剧烈抽搐，她突然夺过实验烧瓶砸碎培养舱，玻璃碎片划破手掌时眼中猩红与清明交替闪烁",
          "next_episode": 9,
          "eva_reason_ori": "时间连贯性(12/20): <IF>中提到的文件发现与米娅的意识恢复之间缺乏明确的时间点延展，导致时间连贯性不足。剧情流程性(15/20): 两个情节通过文件发现和米娅的觉醒连接，但米娅的觉醒过程略显突兀，缺乏自然过渡。事件合理性(16/20): 文件的发现和米娅的觉醒在逻辑上是合理的，但米娅的觉醒过程需要更清晰的解释。主体关联性(18/20): 伊森的行为直接导致了米娅的觉醒，符合主体关联性。逻辑完整性(14/20): <IF>条件包含了过多的事件描述，而非单一可验证条件，<THEN>部分的事件描述过于笼统，缺乏具体性。",
          "eva_score_ori": 75,
          "eva_opt_ori": "原IF包含多重条件（发现文件+解读内容+触发行动），不符合单一可验证条件规范。THEN过度预支下章核心冲突，导致衔接事件失去独立性。根据评估报告聚焦行为触发机制：将伊森执行文件指示作为触发点，衔接米娅因客体刺激产生的意识波动。",
          "old_con": "<IF> **伊森在庄园中发现一份关于解药的关键文件，这份文件揭示了解药的成分和制作方法，并暗示米娅的感染与贝克家族的某个秘密实验有关。伊森意识到必须找到实验室以获取解药的材料** <THEN> **米娅在伊森找到文件后逐渐恢复意识，她开始回忆起自己被感染的经过，并意识到自己曾经参与过实验。米娅的觉醒使她能够控制自己的行为，并决定帮助伊森寻找实验室，揭开贝克家族的秘密。两人联手对抗庄园中的危险，推动剧情进入下一阶段，揭示更多关于解药和感染的真相**",
          "eva_reason_opt": "时间连贯性(15/20): <IF>事件发生在当前章结尾处，但<THEN>事件的描述与下章开篇的时间点不够清晰，缺乏明确的时间过渡。剧情流程性(10/20): 从笔记线索到地下室的跳转缺乏自然的过渡，米娅的剧烈反应显得突兀。事件合理性(15/20): 米娅的反应与故事背景和人物性格有一定的契合，但夺过烧瓶并砸碎培养舱的行为逻辑不够充分。主体关联性(15/20): 触发条件由伊森的行为间接引发，但米娅的反应似乎更像是独立事件。逻辑完整性(10/20): <IF>条件不够单一，包含了多个动作和事件描述，<THEN>事件的独立性不够明确。",
          "eva_score_opt": 65
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "寻找解药: 伊森和米娅在庄园中寻找解药的线索，试图治愈米娅。"
    },
    {
      "episode_id": 8,
      "pre_episode_id": [
        6
      ],
      "episode_goal": "伊森·温特斯的主要目标是揭示贝克家族疯狂行为背后的真相，并找到感染的源头。",
      "episode_scene": "伊森在贝克家族的庄园中探索，这个庄园位于路易斯安那州的偏远地区，环境阴森恐怖，充满了腐朽和被感染的迹象。时间是夜晚，整个庄园被一种不祥的气氛笼罩，伊森必须在这个危险的环境中寻找线索。",
      "episode_desc": "伊森·温特斯在庄园中继续探索，逐渐揭开了贝克家族疯狂背后的真相。他发现感染的源头是一个名叫伊芙琳的小女孩。伊芙琳拥有控制人心的能力，正是她的存在使得贝克家族变得疯狂。伊森在庄园的一个隐秘房间中找到了一些文件，这些文件详细记录了伊芙琳的背景和她的能力。文件显示，伊芙琳是一个实验的产物，被设计成一种生物武器。她的能力不仅能感染人类，还能操控他们的思想和行为。伊森意识到，只有找到并制止伊芙琳，才能结束这场噩梦。他心中充满了复杂的情感，对伊芙琳既有怜悯，也有警惕。他知道，自己必须面对这个小女孩，才能拯救自己和其他被困在庄园中的人。",
      "episode_chars": [
        "伊森·温特斯: 勇敢且执着，决心揭开妻子米娅失踪背后的谜团。在庄园中，他面临着巨大的心理和身体挑战，但仍然坚持不懈地寻找真相。",
        "伊芙琳: 表面上是一个小女孩，实际上是感染的源头，具有控制人心的能力。她的存在使得贝克家族变得疯狂，伊森需要面对她的威胁。",
        "贝克家族: 原本是普通的家庭，但在伊芙琳的影响下变得极其暴力和疯狂。他们的行为和庄园的变化都与伊芙琳的能力有关。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF> **伊森在探索过程中发现了关于伊芙琳的更多信息，揭示她不仅是感染的源头，还具有更深层次的计划，这一发现使得伊森意识到必须尽快阻止她，以防止更大的灾难发生** <THEN> **伊森决定全力以赴去寻找并拯救被困的米娅，同时准备面对伊芙琳的最终形态，揭开她的真实身份并阻止她的计划，这一决心推动他进入下一阶段的对抗，直接引导剧情进入拯救米娅的情节**",
          "next_episode": 10,
          "eva_reason_ori": "时间连贯性(15/20): <IF>部分存在于当前章结尾处，但没有明确的时间点延展，缺乏具体的时间推进; <THEN>部分虽然推动剧情进入下一阶段，但没有独立的衔接事件。剧情流程性(18/20): 跳转事件连接较为流畅自然，<IF>条件在当前情节中可达成，但略显突兀。事件合理性(15/20): 跳转事件基本合理，但<IF>中提到的'更深层次的计划'未在当前情节中充分铺垫，与故事背景稍显脱节。主体关联性(20/20): <IF>条件由伊森的行为直接引发，符合角色动机。逻辑完整性(15/20): <IF>条件较为复杂，不够单一明确，<THEN>部分包含了较多的事件描述，缺乏独立性。",
          "eva_score_ori": 83
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "揭示真相: 伊森发现感染的源头是一个名叫伊芙琳的小女孩，她具有控制人心的能力，贝克家族因她而变得疯狂。"
    },
    {
      "episode_id": 9,
      "pre_episode_id": [
        7
      ],
      "episode_goal": "伊森的主要目标是找到解药，帮助米娅恢复意识，并与她一起对抗贝克家族。",
      "episode_scene": "伊森在路易斯安那州的一个偏僻农场上，夜幕降临，周围环境阴森恐怖。这个农场是贝克家族的居住地，他们被一种神秘的病毒感染，变得极其危险。伊森在寻找解药的过程中，逐渐深入到这个充满危险和谜团的地方。",
      "episode_desc": "在贝克家族庄园的实验室中，米娅逐渐恢复意识，她的眼神不再迷茫，而是充满坚定。她开始帮助伊森寻找解药的线索。两人合作无间，米娅凭借对庄园的熟悉，指引伊森避开潜在的危险。她回忆起曾在庄园某处见过解药的线索，并带领伊森前往。途中，他们遭遇贝克家族的成员，米娅展现出惊人的勇气，与伊森并肩作战。她的觉醒让伊森倍感欣慰，仿佛看到了希望的曙光。在米娅的帮助下，伊森终于找到了解药的关键材料，两人迅速返回实验室，准备制作解药。米娅的觉醒不仅帮助伊森对抗贝克家族，也让他们的关系更加紧密。",
      "episode_chars": [
        "伊森·温特斯: 坚韧不拔，勇敢且充满决心。他是一个普通人，但为了寻找失踪的妻子米娅，他不惜深入险境。在当前情节中，他正在努力寻找解药，以便帮助米娅恢复意识。",
        "米娅·温特斯: 复杂而矛盾，曾被病毒控制但逐渐恢复意识。她是伊森的妻子，在被贝克家族囚禁并感染后，逐渐恢复了自己的意识，并开始帮助伊森对抗贝克家族。",
        "贝克家族: 充满敌意且极其危险。这个家族的成员被神秘病毒感染，变得异常凶残，成为伊森和米娅的主要威胁。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF>伊森将关键材料投入解药配制装置启动合成程序时 <THEN>解药合成触发的能量波动激活米娅体内残留的伊芙琳意识，导致她突然跪地抓住实验台边缘，皮肤下浮现出与三年前录像带里相同的菌丝状纹路",
          "next_episode": 11,
          "eva_reason_ori": "时间连贯性(10/20): <IF>中米娅意识到威胁的过程没有明确的时间点延展，缺乏与当前章结尾的直接衔接。<THEN>中米娅的决定虽然独立，但没有明确的时间衔接。剧情流程性(15/20): 跳转事件在逻辑上可以理解，但缺乏自然的过渡，米娅的意识觉醒与牺牲之间的联系不够流畅。事件合理性(10/20): 米娅的牺牲动机虽然符合故事背景，但其觉醒与牺牲之间的逻辑转变显得突兀。主体关联性(15/20): 触发条件与伊森的行为关联较弱，主要是米娅的独立决策。逻辑完整性(10/20): <IF>包含了多个条件和事件描述，缺乏单一性。<THEN>虽然包含独立事件，但与<IF>的条件关联不够紧密。",
          "eva_score_ori": 60,
          "eva_opt_ori": "原触发条件存在三个核心缺陷：(1)触发主体错位导致关联性断裂 - 米娅的觉醒属于人物自主行为，未通过伊森行为触发；(2)条件复合化导致逻辑完整性不足 - 同时包含意识觉醒与威胁认知双重条件；(3)时间锚点缺失造成连贯性断裂。改进需将触发点锚定在伊森完成解药配置时引发的连锁反应，使米娅的牺牲决策成为伊森关键行为的直接后果。",
          "old_con": "<IF> **米娅在恢复意识的过程中，逐渐意识到伊芙琳对她和伊森的威胁，并深刻理解到只有通过牺牲自己才能彻底解除这种威胁，从而帮助伊森完成他的主要目标，即找到解药并与她一起对抗贝克家族** <THEN> **米娅在意识到这一点后，决定牺牲自己以削弱伊芙琳的力量，为伊森创造一个更有利的机会去击败伊芙琳。这一决定不仅体现了她对伊森的爱和保护，也为接下来的剧情发展奠定了基础，推动伊森继续前行，直面最终的敌人伊芙琳**",
          "eva_reason_opt": "时间连贯性(15/20): <IF>条件存在于当前章结尾处，但<THEN>事件未能构成独立的衔接事件，缺乏时间上的连贯性。剧情流程性(10/20): 跳转事件连接不够流畅，<IF>条件与当前情节的过渡不自然，未能充分体现情节之后的条件。事件合理性(12/20): 解药合成触发的能量波动激活米娅体内的伊芙琳意识，逻辑上存在一定合理性，但与背景设定和人物行为不完全一致。主体关联性(18/20): 触发条件由伊森的行为直接引发，符合主角关联性。逻辑完整性(10/20): <IF>条件描述不够单一，包含事件描述，<THEN>事件未能独立于章节内容复述。",
          "eva_score_opt": 65
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "米娅的觉醒: 在寻找解药的过程中，米娅逐渐恢复意识，并帮助伊森对抗贝克家族。"
    },
    {
      "episode_id": 10,
      "pre_episode_id": [
        8
      ],
      "episode_goal": "伊森·温特斯的主要目标是找到并解救米娅，同时揭开伊芙琳的真实身份并阻止她的计划。",
      "episode_scene": "伊森在贝克家族的庄园中寻找米娅，这个庄园位于路易斯安那州的偏远地区，环境阴森恐怖，充满了腐败和超自然的气息。庄园内充斥着被感染的生物和危险的陷阱，伊森必须在这个充满威胁的环境中找到米娅并揭开隐藏的秘密。",
      "episode_desc": "伊森·温特斯终于在庄园深处找到了米娅，她被困在一个阴暗的房间里。米娅的状态似乎有所好转，她的眼神中闪烁着一丝清醒。伊森试图解救她，但此时伊芙琳的最终形态出现，阻挡了他们的去路。伊森意识到伊芙琳的真实身份，她是一个实验产物，拥有强大的感染和控制能力。为了阻止伊芙琳的计划，伊森必须与她展开最后的对抗。他心中充满了对米娅的担忧和对伊芙琳的警惕，知道只有击败伊芙琳才能拯救米娅和自己。面对伊芙琳的强大力量，伊森毫不退缩，坚定地迎战，誓要结束这场噩梦。",
      "episode_chars": [
        "伊森·温特斯: 坚韧不拔，充满决心和勇气。伊森是一名普通的工程师，为了寻找失踪的妻子米娅而来到贝克家族的庄园。在面对超自然的恐怖和危险时，他表现出非凡的毅力和求生能力。",
        "米娅·温特斯: 神秘复杂，内心挣扎。米娅是伊森的妻子，曾在贝克家族庄园失踪。她被卷入一个超自然的阴谋中，精神状态不稳定，时而表现出敌意，时而渴望被解救。",
        "伊芙琳: 阴险狡诈，具有操控能力。伊芙琳是庄园内的核心威胁，拥有超自然的力量，可以控制和感染他人。她的真实身份和计划是伊森必须揭开的关键谜团。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF>伊森在抵抗伊芙琳攻击时发现她颈部霉菌核心因过度使用能力产生裂痕 <THEN>霉菌核心裂痕导致伊芙琳短暂僵直，伊森趁机将米娅转移至相对安全区域并获取火焰喷射器，为最终对决创造战术优势",
          "next_episode": 12,
          "eva_reason_ori": "时间连贯性(10/20): <IF>中提到的识破伊芙琳的操控能力和找到她的弱点并未在当前plot结尾明确展现，导致时间点不够连贯。<THEN>中提到的最终对决虽然符合时间顺序，但缺乏独立的衔接事件。剧情流程性(15/20): 跳转事件的连接较为流畅，但<IF>中的识破和找到弱点的过程缺乏在当前情节中的铺垫，导致流程性稍显不足。事件合理性(18/20): 伊森识破伊芙琳的能力并找到弱点符合逻辑，与故事背景和人物行为一致。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(10/20): <IF>包含多个条件（识破能力和找到弱点），不够单一且具体，<THEN>过于概括，缺乏独立事件。",
          "eva_score_ori": 73,
          "eva_opt_ori": "原<IF>包含双重条件（识破能力+找到弱点）且未在当前情节结尾体现具体触发动作，<THEN>复述下章核心内容导致衔接断裂。需将触发条件聚焦于主角当前章结尾已启动的关键动作：伊森在与伊芙琳初次对抗时发现其核心弱点（如霉菌核心暴露），该动作既承接当前章战斗开端，又直接引发后续战略调整。",
          "old_con": "<IF> **伊森成功识破伊芙琳的操控能力，并找到她的弱点，从而揭开她的真实身份，阻止她的计划** <THEN> **伊森在与伊芙琳的最终对决中利用这一弱点成功击败她，解救米娅，并为逃离庄园创造机会，最终得以与米娅一同逃出生天，等待救援人员的到来，结束这场噩梦**",
          "eva_reason_opt": "时间连贯性(15/20): <IF>存在于当前章结尾处，但其描述的裂痕并未在当前情节中得到铺垫，影响了时间连贯性。<THEN>衔接事件相对独立，但缺乏承上启下的过渡。剧情流程性(18/20): 跳转事件连接较为流畅自然，<IF>条件在当前情节之后发生，符合剧情流程。事件合理性(15/20): 霉菌核心裂痕的出现和伊森的反应合理，但缺乏前期铺垫，使得事件显得有些突兀。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合角色特性。逻辑完整性(17/20): <IF>条件单一且可验证，但缺乏前期铺垫。<THEN>包含独立事件，但描述略显冗长。",
          "eva_score_opt": 85
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "拯救米娅: 伊森找到米娅并试图解救她，同时必须面对伊芙琳的最终形态，揭开她的真实身份并阻止她的计划。"
    },
    {
      "episode_id": 11,
      "pre_episode_id": [
        9
      ],
      "episode_goal": "伊森·温特斯的主要目标是通过米娅的牺牲来削弱伊芙琳的力量，从而找到机会彻底击败伊芙琳。",
      "episode_scene": "伊森在一个被感染和扭曲的环境中，面对着伊芙琳带来的巨大威胁。此时的背景是一个充满恐怖和绝望的场景，时间接近故事的高潮部分，伊森必须在这个充满危险的环境中找到解决问题的方法。",
      "episode_desc": "米娅意识到伊芙琳的威胁，决心牺牲自己来帮助伊森。她知道伊芙琳的力量源于对她的控制，因此米娅毅然决然地选择与伊芙琳对抗，以便给伊森创造机会。她用尽全力压制体内的感染，努力保持清醒，向伊森传递最后的信息。米娅用坚定的目光望着伊森，示意他必须继续前行，完成他们未竟的使命。伊森心中充满痛苦与不舍，但他明白米娅的牺牲是为了让他有机会击败伊芙琳。他含泪告别米娅，心中燃起复仇的火焰，决心不辜负她的期望，继续向前，迎接最终的对决。",
      "episode_chars": [
        "伊森·温特斯: 坚韧不拔且充满勇气。作为一个普通人，他被卷入了这场恐怖的事件中，为了拯救自己的妻子米娅和自己，他必须面对各种超自然的威胁。",
        "米娅·温特斯: 坚强且富有牺牲精神。她意识到伊芙琳的威胁，并决定以自己的牺牲来帮助伊森，展现出她对伊森的深厚感情和责任感。",
        "伊芙琳: 危险且不可预测。她是这场恐怖事件的核心威胁，具有操控和感染他人的能力，给伊森和米娅带来了巨大的挑战。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF> **米娅意识到伊芙琳的威胁已达到无法控制的程度，并决定牺牲自己以削弱伊芙琳的力量，从而为伊森创造一个击败伊芙琳的机会。米娅的牺牲不仅是出于对伊森的深厚感情和责任感，也是为了保护更多无辜者免受伊芙琳的侵害。** <THEN> **米娅的牺牲成功削弱了伊芙琳的力量，使得伊森能够在失去米娅后独自面对伊芙琳。伊森在孤独与绝望中，凭借坚韧不拔的勇气，最终击败了伊芙琳并逃出庄园。然而，失去米娅的痛苦和心灵的重创将成为伊森接下来必须面对的挑战。**",
          "next_episode": 13,
          "eva_reason_ori": "时间连贯性(15/20): <IF>部分描述了米娅意识到威胁并决定牺牲自己，但没有明确的时间点延展到<THEN>部分，导致时间连贯性不足。剧情流程性(18/20): 整体流程较为自然，但<IF>部分的描述稍显冗长，影响了流畅性。事件合理性(20/20): 米娅的牺牲符合逻辑，与故事背景和人物行为一致。主体关联性(20/20): 触发条件由伊森的情感和行动间接引发，符合要求。逻辑完整性(15/20): <IF>部分包含多个条件和情感描述，而非单一可验证条件，<THEN>部分也包含了过多的事件复述，影响了逻辑的简洁性。",
          "eva_score_ori": 88
        },
        {
          "condition": "<IF>伊森在米娅的遗体旁发现她刻意留下的感染抑制装置，装置表面残留着米娅最后刻下的血清合成公式 <THEN>伊森根据公式指引前往庄园实验室，在实验日志中发现伊芙琳的神经链接存在周期性衰减规律，该发现将直接影响后续战斗策略的制定",
          "next_episode": 16,
          "eva_reason_ori": "时间连贯性(12/20): <IF>部分没有明确时间节点，米娅的牺牲与伊森的意识觉醒之间缺乏直接的时间衔接，导致跳转事件的时间连贯性不足。剧情流程性(15/20): 虽然情感上的转变自然，但从米娅的牺牲到伊森找到对抗方法的逻辑链条不够清晰，缺乏具体的过渡步骤。事件合理性(16/20): 伊森的觉醒与米娅的牺牲相符，但找到对抗方法的过程缺乏详细描述，显得不够合理。主体关联性(18/20): 伊森的行为直接受到米娅的影响，符合主体关联性。逻辑完整性(14/20): <IF>部分包含了多个条件和情感描述，缺乏单一可验证条件，<THEN>部分则包含了多个事件，未能独立于章节内容。",
          "eva_score_ori": 75,
          "eva_opt_ori": "原<IF>包含多重情感觉醒和抽象精神力量描述，缺乏主角可验证的具体行为触发点。原<THEN>直接跨越到战斗结果，与下章谜题探索过程脱节。应聚焦伊森获取关键对抗手段的触发点：1.将触发条件具象化为收集米娅遗留物(直接关联当前章结尾告别动作)；2.衔接事件限定为获得破解操控的核心线索(对应下章解谜阶段)",
          "old_con": "<IF> **伊森在米娅牺牲后，意识到米娅的牺牲不仅是为了削弱伊芙琳的力量，更是为了唤醒他内心深处的勇气和决心。伊森感受到米娅的精神力量在他心中激荡，促使他不再仅仅为了生存而战，而是为了实现米娅的愿望，彻底击败伊芙琳。** <THEN> **伊森在这种新的精神力量的驱动下，找到了一种方法可以有效地对抗伊芙琳的操控能力。他利用这个突破口，成功地削弱了伊芙琳的防御，为最终的对决创造了条件。伊森带着米娅的希望和信念，坚定地走向与伊芙琳的最后对抗，并在最终战胜她后，带着米娅的精神力量逃出庄园。**",
          "eva_reason_opt": "时间连贯性(12/20): <IF>事件发生在米娅的遗体旁，但没有明确的时间延续性，缺乏对时间点的具体描述。剧情流程性(15/20): 从发现装置到前往实验室的过渡较为自然，但缺乏对伊森心理变化的详细刻画。事件合理性(16/20): 装置和公式的发现符合故事背景，但装置的存在显得过于便利，削弱了紧张感。主体关联性(18/20): 伊森的行动直接由米娅的遗留物引发，符合角色动机。逻辑完整性(14/20): <IF>条件包含了事件描述，未完全独立于事件本身；<THEN>事件较为独立，但缺乏对后续策略影响的具体说明。",
          "eva_score_opt": 75
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "米娅的牺牲: 米娅意识到伊芙琳的威胁，选择牺牲自己来帮助伊森击败伊芙琳。"
    },
    {
      "episode_id": 12,
      "pre_episode_id": [
        10
      ],
      "episode_goal": "伊森·温特斯的主要目标是击败伊芙琳，解救米娅并逃离庄园，结束这场噩梦。",
      "episode_scene": "伊森在一个被感染和腐化的庄园中展开行动，这个庄园位于路易斯安那州的偏远地区。庄园被一种神秘的生化力量所控制，环境阴森恐怖，充满了未知的危险和敌意。时间上，伊森正处于与伊芙琳的最终对决前夕，必须在这个充满威胁的环境中找到生存和逃脱的途径。",
      "episode_desc": "伊森·温特斯在庄园深处与伊芙琳展开了最后的对决。伊芙琳的力量异常强大，她试图用幻觉和精神控制扰乱伊森的心智。然而，伊森凭借坚定的意志和对米娅的爱，抵抗住了伊芙琳的攻击。他利用庄园中找到的武器和药剂，逐步削弱伊芙琳的能力。经过一番激烈的战斗，伊森终于成功击败了伊芙琳，解除了她对贝克家族和米娅的控制。随着伊芙琳的消亡，庄园的阴霾逐渐散去，米娅恢复了神智。伊森带着米娅逃离了庄园，迎来了救援人员的到来，结束了这场噩梦般的经历。伊森和米娅在救援人员的帮助下，终于得以重获自由，离开了这个充满恐怖与绝望的地方。",
      "episode_chars": [
        "伊森·温特斯: 坚韧不拔，勇敢且富有求生意志。作为一名普通人，他被卷入了这个恐怖的事件中，为了拯救妻子米娅，他必须面对各种超自然的威胁和恐怖的敌人。",
        "米娅·温特斯: 复杂且神秘，曾被伊芙琳控制。她是伊森的妻子，曾在庄园中失踪多年，现被伊森解救后处于恢复状态，但仍然受到过去经历的影响。",
        "伊芙琳: 邪恶且具有操控能力的生化武器。她是庄园中恐怖事件的核心，能够控制和腐化周围的人和环境，对伊森和米娅构成极大的威胁。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF>伊森在伊芙琳本体溃散后，发现菌核仍在释放感染孢子 <THEN>伊森用最后的高爆弹引爆菌核引发建筑坍塌，冲击波将二人震出主宅区域",
          "next_episode": 14,
          "eva_reason_ori": "时间连贯性(10/20): <IF>部分未明确出现在当前章结尾的时间点，缺乏明确的时间衔接。<THEN>部分虽然描述了事件的结果，但未能有效独立于下章开篇。剧情流程性(15/20): 跳转事件连接较为流畅，但<IF>条件在当前情节中未能充分达成，存在一定的跳跃性。事件合理性(18/20): 跳转事件基本合理，与故事背景和人物行为一致。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合角色设定。逻辑完整性(10/20): <IF>条件较为模糊，未能单一可验证，<THEN>部分包含过多事件描述，未能独立于章节内容。",
          "eva_score_ori": 73,
          "eva_opt_ori": "原<IF>使用主观意识判断导致条件不可验证，且与当前章结尾伊芙琳已被击败的情节冲突。改为基于主角战斗后的具体动作，聚焦触发逃离阶段的关键行为。原<THEN>复述章节内容且包含过多结果事件，调整为聚焦伊芙琳残留能量引发的次生危机，作为衔接逃离与救援的独立事件。",
          "old_con": "<IF> **伊森意识到必须彻底摧毁伊芙琳才能确保米娅的安全，并结束庄园的威胁** <THEN> **伊森在与伊芙琳的最终对决中，利用从庄园中获取的资源和信息，成功击败了伊芙琳。随着伊芙琳的消亡，庄园的腐化力量逐渐消退，伊森得以解救米娅并带她逃离庄园。在逃出庄园后，他们被及时赶到的救援人员接走，终于结束了这场噩梦，进入下一阶段的平静生活**",
          "eva_reason_opt": "时间连贯性(10/20): <IF>条件在当前章结尾没有明确提及菌核的存在，导致时间点的延展性不足。<THEN>事件的独立性较好，但与下章开篇的衔接不够自然。剧情流程性(15/20): 跳转事件的连接较为流畅，但<IF>条件在当前情节中没有充分铺垫，显得有些突兀。事件合理性(18/20): 跳转事件符合逻辑，伊森的行为与故事背景和人物风格一致。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(15/20): <IF>条件不够单一，涉及菌核和孢子的描述，复杂化了条件。<THEN>事件描述清晰，符合要求。",
          "eva_score_opt": 78
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "逃出生天: 伊森成功击败伊芙琳，解救米娅并逃离庄园，最终被救援人员接走，结束了这场噩梦。"
    },
    {
      "episode_id": 13,
      "pre_episode_id": [
        11
      ],
      "episode_goal": "伊森·温特斯的主要目标是独自面对并击败伊芙琳，努力从庄园中逃脱。",
      "episode_scene": "伊森身处贝克家族的庄园，这是一座位于美国路易斯安那州偏远地区的破旧庄园。庄园被一种神秘的生化力量所笼罩，环境阴森恐怖，充满了危险和未知。时间接近故事的尾声，伊森在失去米娅后，孤身一人准备迎接最终的挑战。",
      "episode_desc": "伊森在失去米娅后，独自面对伊芙琳。他心中充满悲痛，却也因米娅的牺牲而燃起复仇的火焰。庄园内阴森的环境让他感到无比孤独，但他知道必须击败伊芙琳才能完成米娅的遗愿。伊芙琳的幻影在他周围徘徊，试图动摇他的意志。伊森紧握手中的武器，坚定地向伊芙琳发起攻击。经过一番激烈的对抗，伊森终于找到了伊芙琳的弱点，并成功击败了她。随着伊芙琳的消失，庄园也开始崩溃。伊森在废墟中艰难地寻找出路，最终逃出生天。然而，尽管身体得以逃脱，伊森的心灵却因失去米娅而受到重创，留下了难以愈合的伤痕。",
      "episode_chars": [
        "伊森·温特斯: 坚韧且执着，普通的工程师，因寻找失踪的妻子米娅而卷入了这场恐怖事件。在失去米娅后，他心灵受到重创，但仍然坚定地面对即将到来的挑战。",
        "伊芙琳: 外表是一个小女孩，实则是一个具有强大精神控制能力的生化武器。她性格扭曲，渴望家庭和亲情，但其行为极具破坏性。在当前情节中，她是伊森必须面对的最终敌人。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF> **伊森意识到他必须独自面对并击败伊芙琳，以结束她对庄园的控制并为米娅的失去复仇，这成为他内心坚定的目标** <THEN> **伊森在与伊芙琳的最终对决中，凭借他的坚韧和执着，成功击败了她，从而解除庄园的威胁。然而，这场胜利并未带来内心的平静，反而让他更加感受到失去米娅的痛苦和孤独，心灵受到重创。尽管如此，他仍然设法逃出庄园，面对一个充满不确定性的未来，推动剧情进入下一个阶段**",
          "next_episode": 15,
          "eva_reason_ori": "时间连贯性(15/20): <IF>部分存在于当前章结尾处的时间点，但<THEN>部分未能完全独立于下章开篇，缺乏明确的时间过渡。剧情流程性(15/20): 跳转事件连接不够流畅自然，<IF>条件的达成与<THEN>事件的发生之间缺乏明显的因果关系。事件合理性(18/20): 跳转事件基本合理，符合逻辑，与故事背景和人物行为一致，但<THEN>部分的情感转变略显突兀。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合角色动机。逻辑完整性(15/20): <IF>条件较为复杂，缺乏单一可验证性，<THEN>事件包含过多情节复述，未能简化为独立事件。",
          "eva_score_ori": 83
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "伊森的孤独: 在失去米娅后，伊森独自面对伊芙琳，最终击败她并逃出庄园，但心灵受到重创。"
    },
    {
      "episode_id": 14,
      "pre_episode_id": [
        12
      ],
      "episode_goal": "伊森的主要目标是击败伊芙琳，解救米娅并逃离庄园。",
      "episode_scene": "伊森在一个被感染的庄园中，时间接近夜晚，环境阴森恐怖，充满了被感染的生物和危险。庄园位于路易斯安那州的偏远地区，周围是茂密的森林和沼泽地，天气阴沉，气氛紧张。",
      "episode_desc": "伊森·温特斯深入贝克家族庄园的最深处，与伊芙琳展开了最后的对决。伊芙琳利用幻觉和精神控制试图扰乱伊森的心智，制造各种恐怖的幻象，试图让伊森屈服。然而，伊森凭借对妻子米娅的爱和坚定的意志，抵抗住了这些精神攻击。他在庄园中搜寻到了一些关键的武器和药剂，这些物品帮助他逐步削弱了伊芙琳的能力。在一场激烈的战斗中，伊森利用手中的武器与伊芙琳展开殊死搏斗，最终成功击败了她，解除了她对贝克家族和米娅的控制。随着伊芙琳的消亡，庄园的阴霾逐渐散去，米娅恢复了神智，伊森带着米娅逃离了庄园。",
      "episode_chars": [
        "伊森·温特斯: 坚韧不拔，勇敢且充满求生欲望。此时他正在努力寻找妻子米娅，并试图从这个被感染的庄园中逃脱。他面对着巨大的危险，但始终保持冷静和决心。",
        "米娅·温特斯: 复杂且神秘，曾被感染，性格在温柔和暴力之间摇摆不定。她是伊森的妻子，目前被困在庄园中，处于被感染的状态，时而清醒，时而受感染控制。",
        "伊芙琳: 邪恶且具有操控能力的生物，外表是一个小女孩。她是庄园感染的源头，具有强大的精神控制能力，能够操控被感染者的行为。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF>伊森带着米娅逃离庄园时发现她瞳孔泛起菌丝微光 <THEN>伊森意识到感染残留，折返寻找根源时遭遇时空扭曲",
          "next_episode": -1,
          "eva_reason_ori": "时间连贯性(10/20): 当前<IF>击败伊芙琳的时间点与下一个plot的开篇不一致，存在时间断层，未能有效衔接。剧情流程性(10/20): 跳转事件缺乏自然过渡，伊森击败伊芙琳后直接迎来救援人员的到来显得突兀，缺乏过渡情节。事件合理性(15/20): 救援人员的到来在故事背景中未得到充分铺垫，显得不够合理。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合要求。逻辑完整性(15/20): <IF>条件单一且可验证，但<THEN>部分包含了较多事件描述，削弱了独立性。",
          "eva_score_ori": 70,
          "eva_opt_ori": "原跳转事件与后续剧情存在根本矛盾：当前章结局已明确伊芙琳被击败且米娅存活，但下章开篇却呈现米娅死亡且伊芙琳复活状态。改进需建立时间循环/幻觉嵌套结构，通过米娅的异常征兆暗示精神控制未被完全清除，既保持恐怖生存风格又解决时间断层问题",
          "old_con": "<IF>击败伊芙琳 <THEN>伊森和米娅在庄园外迎来了救援人员的到来。两人终于得以重获自由，离开了这个充满恐怖与绝望的地方。在救援直升机上，伊森紧紧握住米娅的手，虽然身体疲惫不堪，但心中充满了对未来的希望。然而，伊森的眼神中仍然流露出一丝不安，仿佛预示着这场噩梦并未完全结束。",
          "eva_reason_opt": "时间连贯性(10/20): <IF>事件发生在逃离时，时间点不够明确且与下个plot的独立性不足。剧情流程性(10/20): 跳转事件的流畅性欠佳，伊森的折返与时空扭曲的连接显得突兀。事件合理性(15/20): 伊森发现米娅的感染残留是合理的，但时空扭曲缺乏背景支持。主体关联性(15/20): 触发条件由伊森的观察引发，但与其行为的直接关联性不强。逻辑完整性(10/20): <IF>条件不够单一明确，<THEN>事件描述过于复杂，缺乏独立性。",
          "eva_score_opt": 60
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "噩梦终结: 伊森成功击败伊芙琳，解救米娅并逃离庄园，最终被救援人员接走，结束了这场噩梦。"
    },
    {
      "episode_id": 15,
      "pre_episode_id": [
        13
      ],
      "episode_goal": "伊森的主要目标是独自面对并击败伊芙琳，努力从恐怖的环境中逃出生天。",
      "episode_scene": "伊森在失去米娅后，独自一人在贝克家族庄园的地下实验室中。这个实验室隐藏在路易斯安那州的偏远地区，周围环境阴森恐怖，充满了未知的危险和敌意。时间是夜晚，整个庄园被黑暗笼罩，只有微弱的灯光和阴影在墙壁上摇曳。",
      "episode_desc": "伊森·温特斯在贝克家族庄园的废墟中独自前行，心中充满了失去米娅的痛苦和对伊芙琳的仇恨。庄园的阴影似乎在无声地嘲笑他的孤独，但伊森知道，只有击败伊芙琳才能完成米娅的遗愿。他紧握武器，面对伊芙琳的幻影毫不退缩。伊芙琳试图用幻象扰乱他的心智，但伊森凭借坚定的意志，逐渐找到了她的弱点。经过一场激烈的对抗，伊森终于成功击败了伊芙琳。随着她的消失，庄园开始崩溃。伊森在废墟中艰难地寻找出路。",
      "episode_chars": [
        "伊森·温特斯: 坚韧不拔，充满勇气和决心。此时他已经经历了重重磨难，失去了妻子米娅，但仍然坚持不懈地追求真相和生存的希望。在面对伊芙琳的威胁时，他表现出极大的勇气和毅力。",
        "伊芙琳: 阴险狡诈，具有操控和操纵他人的能力。她是一个神秘而危险的存在，能够影响他人的心智，并对伊森构成了巨大的威胁。她是伊森在庄园中必须面对的最终挑战。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF>成功击败伊芙琳 <THEN>庄园的崩溃加速，伊森在废墟中艰难地寻找出路，最终逃出生天。然而，尽管身体得以逃脱，伊森的心灵却因失去米娅而受到重创，未来充满不确定性。伊森站在庄园外的空地上，望着逐渐沉入黑暗的废墟，心中充满了对未来的迷茫和对过去的悔恨。远处传来警笛声，似乎预示着新的开始，但伊森知道，心灵的伤口并不会因此愈合。",
          "next_episode": -1,
          "eva_reason_ori": "时间连贯性(15/20): <IF>成功击败伊芙琳与当前章节结尾的时间点一致，但<THEN>部分的庄园崩溃加速与伊森逃出生天的描述略显冗长，未能紧凑衔接。剧情流程性(18/20): 整体流程较为自然，伊森的逃脱与心灵创伤的描述顺畅，但警笛声的出现稍显突兀。事件合理性(17/20): 庄园崩溃与伊森的逃脱符合逻辑，但心灵创伤的描写与故事背景稍显重复。主体关联性(20/20): 伊森的行为直接引发了庄园的崩溃和后续事件。逻辑完整性(15/20): <IF>条件明确，但<THEN>部分包含了过多的事件描述，削弱了独立性。",
          "eva_score_ori": 85
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "孤独的胜利: 伊森在失去米娅后独自击败伊芙琳，虽然逃出生天，但心灵受到重创，未来充满不确定性。"
    },
    {
      "episode_id": 16,
      "pre_episode_id": [
        11
      ],
      "episode_goal": "伊森·温特斯的主要目标是逃离庄园，并在此过程中寻求拯救米娅的机会。",
      "episode_scene": "在路易斯安那州的一个偏远庄园中，夜幕笼罩下的庄园充满了恐怖和神秘。伊森在寻找失踪的妻子米娅的过程中，深入这个被诅咒的地方，面对着各种超自然现象和危险生物的威胁。",
      "episode_desc": "伊森·温特斯在米娅的帮助下，深入贝克家族庄园的深处，面对最终的敌人伊芙琳。米娅用尽全力压制体内的感染，保持清醒，为伊森创造机会。伊森在庄园中穿梭，解开各种谜题，收集必要的资源和武器，最终与伊芙琳展开激烈的对决。在对战过程中，伊森需要躲避伊芙琳的攻击，同时寻找她的弱点进行反击。随着战斗的进行，伊森逐渐揭开伊芙琳的真实身份，并意识到她的操控能力来源于她体内的特殊感染源。",
      "episode_chars": [
        "伊森·温特斯: 坚韧且富有决心。在寻找妻子米娅的过程中，他展现出极大的勇气和毅力，面对恐怖的环境和敌人毫不退缩。",
        "米娅·温特斯: 内心充满矛盾和挣扎。她曾被感染并被迫做出可怕的事情，但在最后关头，她选择帮助伊森，展现出对丈夫的深切爱意和自我救赎的决心。",
        "伊芙琳: 具有操控能力的生物，外表为一个小女孩。她是庄园中一切恐怖事件的源头，性格扭曲且危险，渴望家庭和控制他人。"
      ],
      "extra_info": [],
      "triggers": [
        {
          "condition": "<IF>伊森成功击败伊芙琳 <THEN>伊森在击败伊芙琳后，庄园开始崩溃。他带着米娅的希望，艰难地逃出庄园。尽管米娅已经不在，但她的勇敢和爱将永远伴随伊森。伊森站在庄园外，望着燃烧的废墟，心中充满对米娅的怀念和对未来的坚定信念。",
          "next_episode": -1,
          "eva_reason_ori": "时间连贯性(15/20): 虽然伊森击败伊芙琳后庄园开始崩溃是一个合理的时间延展，但缺乏对时间点的明确过渡描述，导致衔接不够清晰。剧情流程性(18/20): 整体跳转事件流畅自然，但伊森在击败伊芙琳后直接进入逃亡阶段，缺乏对战后心理状态的过渡描写。事件合理性(17/20): 庄园崩溃符合逻辑，但伊森的心理状态变化过于迅速，未充分体现恐怖生存和心理惊悚的风格。主体关联性(20/20): 触发条件由伊森的行为直接引发，符合角色设定。逻辑完整性(16/20): <IF>条件明确，但<THEN>部分包含了过多的情感描写，影响了独立事件的呈现。",
          "eva_score_ori": 86
        }
      ],
      "message_pairs": [],
      "episdoe_desc_brief": "米娅的救赎: 米娅在最后时刻帮助伊森击败伊芙琳，虽然自己牺牲，但伊森带着她的希望逃出庄园。"
    }
  ]
}

# %%
data = {"name": "Alice", "age": 25}
print(f'{data["age"]}')
# Out:
# 25

# %%
a ="""
{
    "伊森·温特斯": "身份: 普通人, 后来成为生存者。性格: 坚韧不拔, 勇敢, 但也有些许的疑虑和不安。经历: 伊森是一名普通的系统工程师, 收到失踪三年的妻子米娅的消息后前往路易斯安那州寻找她。在贝克家族的庄园中，他经历了一系列恐怖事件，逐渐揭开了庄园背后的秘密，并与新型菌兽展开了生死搏斗。",
    "米娅·温特斯": "身份: 伊森的妻子, 隐藏身份为生物武器研究员。性格: 复杂, 在温柔与隐秘之间徘徊。经历: 米娅在失踪后被发现与贝克家族有联系，她曾是一个生物武器项目的参与者。被伊森找到后，她的真实身份和过去逐渐被揭露，面对伊森时，她在被控制与自我意识之间挣扎。",
    "伊芙琳": "身份: 生物武器, 被称为'小女孩'。性格: 表面天真, 实则操控欲强。经历: 伊芙琳是一个被创造出来的生物武器，具有控制他人心智的能力。她被贝克家族收养后，逐渐失控，导致整个庄园的悲剧。她的存在是伊森和米娅所面临的最大威胁。",
    "杰克·贝克": "身份: 贝克家族的家长, 被感染后变得疯狂。性格: 原本是一个普通的农夫, 但在感染后变得极端暴力和不可预测。经历: 杰克在被伊芙琳感染后，失去了理智，成为了庄园中的主要威胁之一。他多次与伊森对抗，展现出惊人的再生能力和攻击性。",
    "贝克夫人": "身份: 贝克家族的女主人, 被感染后变得恐怖。性格: 原本慈爱, 但被感染后变得偏执和凶残。经历: 她在感染后对伊森产生了极大的敌意，利用庄园中的环境和陷阱对付入侵者。她的变化是贝克家族悲剧的一个缩影。",
    "佐伊·贝克": "身份: 贝克家族的女儿, 唯一未被完全感染的人。性格: 机智, 勇敢, 渴望逃离。经历: 佐伊在家族被感染后，努力保持清醒，并试图帮助伊森逃离庄园。她提供了关键的帮助和信息，是伊森在庄园中少数的盟友之一。",
    "新型菌兽": "身份: 由感染者变异而成的生物。性格: 无意识, 但极具攻击性。经历: 这些生物是伊芙琳能力失控的产物，遍布于庄园各处，对任何入侵者构成严重威胁。它们的存在使得逃离庄园变得更加困难。"
}
"""
print(json.dumps(json.loads(a),indent=2,ensure_ascii=False))
# Out:
# {
#   "伊森·温特斯": "身份: 普通人, 后来成为生存者。性格: 坚韧不拔, 勇敢, 但也有些许的疑虑和不安。经历: 伊森是一名普通的系统工程师, 收到失踪三年的妻子米娅的消息后前往路易斯安那州寻找她。在贝克家族的庄园中，他经历了一系列恐怖事件，逐渐揭开了庄园背后的秘密，并与新型菌兽展开了生死搏斗。",
#   "米娅·温特斯": "身份: 伊森的妻子, 隐藏身份为生物武器研究员。性格: 复杂, 在温柔与隐秘之间徘徊。经历: 米娅在失踪后被发现与贝克家族有联系，她曾是一个生物武器项目的参与者。被伊森找到后，她的真实身份和过去逐渐被揭露，面对伊森时，她在被控制与自我意识之间挣扎。",
#   "伊芙琳": "身份: 生物武器, 被称为'小女孩'。性格: 表面天真, 实则操控欲强。经历: 伊芙琳是一个被创造出来的生物武器，具有控制他人心智的能力。她被贝克家族收养后，逐渐失控，导致整个庄园的悲剧。她的存在是伊森和米娅所面临的最大威胁。",
#   "杰克·贝克": "身份: 贝克家族的家长, 被感染后变得疯狂。性格: 原本是一个普通的农夫, 但在感染后变得极端暴力和不可预测。经历: 杰克在被伊芙琳感染后，失去了理智，成为了庄园中的主要威胁之一。他多次与伊森对抗，展现出惊人的再生能力和攻击性。",
#   "贝克夫人": "身份: 贝克家族的女主人, 被感染后变得恐怖。性格: 原本慈爱, 但被感染后变得偏执和凶残。经历: 她在感染后对伊森产生了极大的敌意，利用庄园中的环境和陷阱对付入侵者。她的变化是贝克家族悲剧的一个缩影。",
#   "佐伊·贝克": "身份: 贝克家族的女儿, 唯一未被完全感染的人。性格: 机智, 勇敢, 渴望逃离。经历: 佐伊在家族被感染后，努力保持清醒，并试图帮助伊森逃离庄园。她提供了关键的帮助和信息，是伊森在庄园中少数的盟友之一。",
#   "新型菌兽": "身份: 由感染者变异而成的生物。性格: 无意识, 但极具攻击性。经历: 这些生物是伊芙琳能力失控的产物，遍布于庄园各处，对任何入侵者构成严重威胁。它们的存在使得逃离庄园变得更加困难。"
# }

# %%
import os
import re
import sys
import time
import json
import copy
import logging
import argparse
import jsonlines
from tqdm import tqdm
from datetime import datetime
from langchain.prompts import PromptTemplate 
from langchain.schema import (
    AIMessage,
    HumanMessage,
    SystemMessage
)
from loguru import logger
logger.remove()
logger.add(sys.stdout, level="INFO")
logger.debug("This is a debug message")  # 不会显示
logger.info("This is an info message")   # 会显示
logger.warning("This is a warning message")  # 会显示
logger.error("This is an error message")  # 会显示
logger.critical("This is a critical message")  # 会显示


parent_dir = os.path.dirname(os.path.abspath(''))

sys.path.append(parent_dir)
from llm import AzureLLM, GPTProxyLLM, DeepSeekLLM

llm_gpt = GPTProxyLLM()
llm_deepseek = DeepSeekLLM()
# Out:
# 2025-03-31 19:51:09.016 | INFO     | __main__:<module>:22 - This is an info message
# 2025-03-31 19:51:09.017 | WARNING  | __main__:<module>:23 - This is a warning message
# 2025-03-31 19:51:09.018 | ERROR    | __main__:<module>:24 - This is an error message
# 2025-03-31 19:51:09.018 | CRITICAL | __main__:<module>:25 - This is a critical message

# %%
# 拆分think
def ds_think_analysis(model_chat:str):
    model_chat_list = model_chat.split("<thinking>") 
    if len(model_chat_list) == 2:
        model_think = model_chat_list[0].strip()
        model_ans = model_chat_list[1].strip()
    elif len(model_chat_list) == 1:
        model_think = ""
        model_ans = model_chat_list[0].strip()
        # print("Warning! no <thinking> in res")
    else:
        logger.error("Warning! too many <thinking> in res")
        
    return model_think, model_ans

# llm及处理
def llm_chat_analysis(llm_model_name:str, llm_prompt:str, res_json_type:str):
    # print(llm_prompt)
    
    if llm_model_name == "deepseek-r1":
        llm_model = DeepSeekLLM()
    elif llm_model_name == "gpt-4o":
        llm_model = GPTProxyLLM(temperature=0.5)
    else:
        logger.error("wrong llm model type")

    try_count = 0
    while try_count<3:
        try_count += 1
        try:

            if type(llm_prompt) == str:
                res_llm = llm_model.chat(llm_prompt)
                # print(res_llm)
            elif type(llm_prompt) == dict:
                res_llm = llm_model.chat(llm_prompt["query"],llm_prompt["example"],llm_prompt["system_prompt"])

            else:
                logger.error(f"wrong prompt type {type(llm_prompt)}: {llm_prompt}")


            if llm_model_name == "deepseek-r1":
                res_think, res_ans = ds_think_analysis(res_llm)
                res_think = res_think.replace('\n\n','\n').strip()
            else:
                res_think = ""
                res_ans = res_llm
            res_ans = res_ans.strip()

            try:
                cleaned_json_string = res_ans.split('```json')[1].split('```')[0].strip()
            except:
                try:
                    cleaned_json_string = res_ans.split('```')[1].strip()
                except:
                    cleaned_json_string = res_ans
            cleaned_json_string = cleaned_json_string.strip()

            if res_json_type == "str":
                return res_think, cleaned_json_string
            if res_json_type == "int":
                return res_think, int(cleaned_json_string)
            # print(cleaned_json_string)
                    
            try:
                res_json_load = json.loads(cleaned_json_string)
            except:
                try:
                    cleaned_json_string1 = cleaned_json_string
                    if not cleaned_json_string1.startswith("{"):
                        cleaned_json_string1 = "{\n" +cleaned_json_string1
                    if not cleaned_json_string1.endswith("}"):
                        cleaned_json_string1 = cleaned_json_string1 + "\n}" 
                    res_json_load = json.loads(cleaned_json_string1)
                except Exception as e:
                    try:
                        cleaned_json_string1 = cleaned_json_string
                        cleaned_json_string1 = cleaned_json_string1.strip("\"").strip("main").strip("\"").strip(":")
                        res_json_load = json.loads(cleaned_json_string1)
                    except:
                        cleaned_json_string1 = cleaned_json_string.replace('[',"{").replace.replace(']',"}")
                        
                
            if type(res_json_load) == dict:
                try:
                    res_json_load = res_json_load["main"] 
                except:
                    pass
            
            
            if res_json_type == "dict":
                res_json = {}
                if type(res_json_load) == dict:
                    res_json = res_json_load
                elif type(res_json_load) == list:
                    for item in res_json_load:
                        # 多个str组成的list：['伊森·温特斯: 主角...',...]
                        if type(item) == str:
                            item1 = item.split(":")
                            res_json[item1[0].strip()] = item1[1].strip()
                        # 多个dict组成的list：[{'伊森·温特斯': '主角...'},...,{}]
                        elif type(item) == dict:
                            res_json.update(item)
                # 几率低, 比较粗糙的处理方法, 可以改进
                # elif type(res_json_load) == str:
                #     pass
                else:
                    logger.error(f"Warning! res_json_load type error {type(res_json_load)}, need {res_json_type}")

            elif res_json_type == "list":
                res_json = []
                if type(res_json_load) == list:
                    res_json = res_json_load
                elif type(res_json_load) == dict:
                    res_json = []
                    for key in res_json_load.keys():
                        res_json.append(f"{key}: {res_json_load[key]}")
                # 几率低, 比较粗糙的处理方法, 可以改进
                elif type(res_json_load) == str:
                    res_json.append(res_json_load)
                else:
                    logger.error(f"Warning! res_json_load type error {type(res_json_load)}, need {res_json_type}")

            return res_think, res_json
        except Exception as e:
            logger.error(f"重新生成, 发生错误：{e}")

# %%
prompt_gen_story_template = {
    # 提取背景
    "create_storyline_keywords": PromptTemplate(
        template = """你是一个资深作家, 接下来请根据我的关键词设计一个符合关键词的一个故事大纲
剧情要求如下：** {requirements} **

要求：
1. 故事大纲需要包含关键词的风格, 应该将不同关键词的剧情进行融合，不要出现缺失某个关键词的风格， 根据关键词确定故事题材、情绪
2. 剧情合理有逻辑，不要出现剧情矛盾
3. 剧情大纲有深度有新意，突出反转与冲突，
4. 有吸引力，情感准确传达，确保有代入感，开头应该足够吸引人
5. 单主角，以主角的视角展开剧情，每个剧情主角都应该出现
6. 故事大概有十个章节，每个章节都应该有一些核心事件发生，且不同章节的事件应该有所差异
7. 故事大纲中的时间跨度不要太大
8. 像故事一样叙述，不要出现大纲的格式，不要出现“本故事”，“主角”这种令人出戏的词汇
9. 不要简单的出现关键词，关键是指引故事的情节，而不是让故事中出现这个词，根据要根据关键词设计故事大纲内容，将关键词形容的事件融入故事情节   


输出格式:使用json格式输出，最终是一个list，每个list项是一个str格式，为一个章节的详细剧情"
示例如下：
[
    "(章节1具体剧情)",
    "(章节2具体剧情)",
    ...
]
    """,
        input_variables=["requirements"],
    ),
    "sumary_title": PromptTemplate(
        template = """有一段剧情和这段剧情的关键词，将它起一个标题
要求：精简，15个字以内，文艺且能体现故事，不要与现有的小说或者游戏等标题重复
只返回标题，不要返回其他内容

要求如下：
{requirements}
剧情如下：
{plot}
        """,
        input_variables=["plot", "requirements"],
    ),
    "sumary_title_plot": PromptTemplate(
        template = """有一段剧情，将它精简成一句话,作为章节的标题，不要书名号等其他内容
剧情如下：
{plot}
        """,
        input_variables=["plot"],
    ),

}

def create_storyline(keywords:str):
    prompt1 = prompt_gen_story_template['create_storyline_keywords'].format(keywords=keywords)
    _,story_plot = llm_chat_analysis("gpt-4o", prompt1, "list")

    prompt2 = prompt_gen_story_template['sumary_title'].format(plot='\n'.join(story_plot), keywords=keywords)
    _,story_title = llm_chat_analysis("gpt-4o", prompt2, "str")

    data_output_file = f"{data_output_folder}{story_title}_gen.jsonl"
    # print(story_plot)
    print(len(story_plot))
    for plot_i in tqdm(story_plot):

        # print(plot_i)
        prompt3 = prompt_gen_story_template['sumary_title_plot'].format(plot=plot_i)
        _,sum_plot_i = llm_chat_analysis("gpt-4o", prompt3, "str")
        # print(sum_plot_i)
        content_plot_sum = sum_plot_i.strip('') + '\n\n' + plot_i.replace('\n\n','\n').strip('')

        with jsonlines.open(data_output_file, mode='a') as writer:
            writer.write(content_plot_sum)


data_output_folder = f"storyline_generator/source_stories/extra_story_output/"

# %%
keyword = "末世 男主 爱情 背叛 虐恋 残酷 好结局"
print(story_requirements)
prompt1 = prompt_gen_story_template['create_storyline_keywords'].format(requirements=story_requirements)
# print(prompt1)
_,story_plot = llm_chat_analysis("gpt-4o", prompt1, "list")

prompt2 = prompt_gen_story_template['sumary_title'].format(plot='\n'.join(story_plot), requirements=story_requirements)
_,story_title = llm_chat_analysis("gpt-4o", prompt2, "str")
print(story_title)
# print(story_plot)
print(len(story_plot))
for plot_i in tqdm(story_plot):

    # print(plot_i)
    prompt3 = prompt_gen_story_template['sumary_title_plot'].format(plot=plot_i)
    _,sum_plot_i = llm_chat_analysis("gpt-4o", prompt3, "str")
    # print(sum_plot_i)
    content_plot_sum = sum_plot_i.strip('') + '\n\n' + plot_i.replace('\n\n','\n').strip('')
    print(content_plot_sum)
    # break
# Out:
# 故事主角是人类主角(女性); 故事发生于现代的平行世界, 整体是个好结局, 故事风格/氛围是黑色幽默的
# 故事类型关键词如下:
# 救赎 生存竞技 克苏鲁诡谲 悬疑推理 言情 逆袭 道德困境 养成 轻松
# 你是一个资深作家, 接下来请根据我的关键词设计一个符合关键词的一个故事大纲
# 剧情要求如下：** 故事主角是人类主角(女性); 故事发生于现代的平行世界, 整体是个好结局, 故事风格/氛围是黑色幽默的
# 故事类型关键词如下:
# 救赎 生存竞技 克苏鲁诡谲 悬疑推理 言情 逆袭 道德困境 养成 轻松 **
#
# 要求：
# 1. 故事大纲需要包含关键词的风格, 应该将不同关键词的剧情进行融合，不要出现缺失某个关键词的风格， 根据关键词确定故事题材、情绪
# 2. 剧情合理有逻辑，不要出现剧情矛盾
# 3. 剧情大纲有深度有新意，突出反转与冲突，
# 4. 有吸引力，情感准确传达，确保有代入感，开头应该足够吸引人
# 5. 单主角，以主角的视角展开剧情，每个剧情主角都应该出现
# 6. 故事大概有十个章节，每个章节都应该有一些核心事件发生，且不同章节的事件应该有所差异
# 7. 故事大纲中的时间跨度不要太大
# 8. 像故事一样叙述，不要出现大纲的格式，不要出现“本故事”，“主角”这种令人出戏的词汇
# 9. 不要简单的出现关键词，关键是指引故事的情节，而不是让故事中出现这个词，根据要根据关键词设计故事大纲内容，将关键词形容的事件融入故事情节
#
#
# 输出格式:使用json格式输出，最终是一个list，每个list项是一个str格式，为一个章节的详细剧情"
# 示例如下：
# [
#     "(章节1具体剧情)",
#     "(章节2具体剧情)",
#     ...
# ]
#
# 《异次元竞技场的救赎之旅》
# 10
#  10%|█         | 1/10 [00:01<00:17,  1.98s/it]
# 艾米莉亚潜入地下竞技场揭露黑暗真相
#
# 在一个被克苏鲁神话笼罩的平行世界，年轻的女记者艾米莉亚正面临人生的低谷。她因为一篇揭露黑暗势力的报道而被迫离开工作岗位，生活陷入窘境。然而，一封神秘的邀请函将她引入一个地下生存竞技场，传闻这里每年都会消失一批人。艾米莉亚决定以记者的身份潜入，揭开真相。
# ...

# %%
import random

all_keyword = []

def keywords_generator():
    confront_keywords = [["好结局","悲剧"],["男性","女性"],["人类主角","非人类主角"],["现代","历史","未来","穿越"],["现实世界","平行世界","架空世界"],["黑暗压抑","轻松治愈","沙雕搞笑","黑色幽默","热血励志","荒诞讽刺"]]
    fusion_keywords = [["爱情","亲情","友情","背叛","虐恋","仇恨","救赎","复仇"],["悬疑推理","权谋斗争","恐怖惊悚","军事战争","克苏鲁诡谲","生存竞技","青春","魔法","科幻","玄幻仙侠","都市","现实","游戏","言情","末世"],["高智商","反套路","扮猪吃老虎","道德困境","黑色幽默","轻松","养成","逆袭"]]

    confront_keywords_list = []
    for i in range(len(confront_keywords)):
        confront_keywords_list.append(confront_keywords[i][random.randint(0, len(confront_keywords[i])-1)])

    story_requirements = f"故事主角是{confront_keywords_list[2]}({confront_keywords_list[1]}); 故事发生于{confront_keywords_list[3]}的{confront_keywords_list[4]}, 整体是个{confront_keywords_list[0]}, 故事风格/氛围是{confront_keywords_list[5]}的\n故事类型关键词如下:\n"
    # print(story_keywords_list)

    for i in range(len(fusion_keywords)):
        random_num = random.randint(0, min(4,len(fusion_keywords[i])))
        random_selection = random.sample(fusion_keywords[i], random_num)
        story_requirements += " ".join(random_selection)+" "

    story_requirements = story_requirements.strip()

    # if story_requirements in all_keyword:
    #     pass
    # else:
    #     print(story_requirements)
    #     all_keyword.append(story_requirements)

    return story_requirements



print(keywords_generator())
# Out:
# 故事主角是非人类主角(男性); 故事发生于未来的平行世界, 整体是个悲剧, 故事风格/氛围是沙雕搞笑的
# 故事类型关键词如下:
#  悬疑推理 克苏鲁诡谲 生存竞技 养成 黑色幽默 反套路

# %%
input_all_folder = "source_stories/extra_story_output/"
storyline_input_folder = input_all_folder + "extra_storyline/"
import os
import json
for filename in os.listdir(storyline_input_folder):
    if not filename.endswith(".jsonl"):
        continue
    file_path = os.path.join(storyline_input_folder, filename)  # 构建完整文件路径
    
    print(f"正在读取文件: {os.path.basename(file_path)}")  # 打印当前文件名
    
    # 读取 JSONL 文件内容
    with open(file_path, "r", encoding="utf-8") as f:
        for line in f:
            json_data = line.strip()
            if json_data:
                try:
                    data = json.loads(json_data)
                    print(data)  # 打印解析后的数据（可选）
                except json.JSONDecodeError as e:
                    print(f"JSON 解析错误（文件 {os.path.basename(file_path)}）: {e}")
# Out:
# 正在读取文件: 神探狄仁杰1-使团喋血记_extra.jsonl
# 第一部 使团喋血记 第一章 突厥客喋血甘南道
#
# 第一部 使团喋血记 第一章 突厥客喋血甘南道
#
# 大唐与突厥多年战争后，突厥内部主和派占优并派使团议和，武则天在长安隆重接待使团并强调和平重要性。突厥特使赠送珍宝，武则天为示友好决定将翌阳郡主嫁给突厥可汗。途中郡主遭伏击，羽林卫全军覆没，幕后青袍人自称“蝮蛇”并救出被拷打的刘金。武则天怀疑逆党作乱，命令封锁长安四门严查，突厥使者返程受阻，局势紧张。
# 始毕可汗因不满等待而试图强行出城，与虎敬晖发生冲突，后在武三思护送下离开并扬言报复。与此同时，武则天得知突厥使团遇害，怀疑有内奸，命令通缉失踪的护卫队队正李元芳，并召狄仁杰调查案件。狄仁杰通过细致推理揭露谋杀案真相，赢得衙役们的钦佩。另一方面，刘金与金木兰在山洞中讨论隐藏的重要名单，武则天对朝廷被逆贼玩弄感到愤怒，并加紧追捕李元芳，希望狄仁杰能尽快破案以缓和与突厥的紧张关系。
# 第一部 使团喋血记 第二章 探奇案狄公重出山
#
# 第一部 使团喋血记 第二章 探奇案狄公重出山
#
# 夜深时，灵州城内捕快围捕青年，神秘人建议他投奔狄仁杰以求自保。狄仁杰在调查使团遇害案时，收到关于李元芳的紧急文书，怀疑其行为异常。与此同时，金木兰与于风策划行动，涉及李元芳和狄仁杰。李元芳被陷害为谋杀使团的罪犯，遭追捕并受重伤，求助狄仁杰。狄仁杰推测李元芳被幕后主使利用，行踪被故意泄露。狄仁杰准备随千牛卫赴京处理紧急事务，但怀疑传旨者身份，最终遭到袭击。
# 李元芳和狄仁杰揭露假钦差的阴谋，成功躲避追捕并计划出城，同时武则天担忧突厥特使被杀可能引发冲突，强调狄仁杰的重要性。狄仁杰调查发现“蝮蛇”与土窑失火和使团被杀有关，推测其目的是营救神秘人物。武则天在寺庙内与狄仁杰重聚，揭露十年前谋反事件，并讨论刘金的危害。狄仁杰推测假突厥使团的目的是营救刘金，并向武则天呈交奏章。
# 第一部 使团喋血记 第三章 狄仁杰初探幽州地
#
# 第一部 使团喋血记 第三章 狄仁杰初探幽州地
#
# ...
